# %%
import os
import pandas as pd

from datetime import datetime

PATH = "../dfp_cia_aberta_2024"

forms = [
    "BPA_con",
    "BPP_con",
    "DFC_MD_con",
    "DFC_MI_con",
    "DMPL_con",
    "DRA_con",
    "DRE_con",
    "composicao",
    "DVA_con",
    "parecer",
]

ORDEM_EXERC = "ÚLTIMO"
mapping = {
    "CNPJ": "CNPJ_CIA",
    "REPORT_DATE": "DT_REFER",
    "COMPANY_NAME": "DENOM_CIA",
    "CVM_CODE": "CD_CVM",
    "DFP_GROUP": "GRUPO_DFP",
    "VERSION": "VERSAO",
    "CURRENCY": "MOEDA",
    "ANALYSIS_START_PERIOD_DATE": "DT_INI_EXERC",
    "ANALYSIS_END_PERIOD_DATE": "DT_FIM_EXERC",
    "ACCOUNT_NUMBER": "CD_CONTA",
    "ACCOUNT_NAME": "DS_CONTA",
    "ACCOUNT_VALUE": "VL_CONTA",
    "IS_FIXED_ACCOUNT": "ST_CONTA_FIXA",
}

# %% [markdown]
# # Processamento
#
# - Balanço Patrimonial Ativo (BPA)
# - Balanço Patrimonial Passivo (BPP)
# - Demonstração de Fluxo de Caixa - Método Direto (DFC-MD)
# - Demonstração de Fluxo de Caixa - Método Indireto (DFC-MI)
# - Demonstração das Mutações do Patrimônio Líquido (DMPL)
# - Demonstração de Resultado Abrangente (DRA)
# - Demonstração de Resultado (DRE)
# - Demonstração de Valor Adicionado (DVA)

# %%
result_forms = []
for form in [
    "BPA_con",
    "BPP_con",
    "DFC_MD_con",
    "DFC_MI_con",
    "DMPL_con",
    "DRA_con",
    "DRE_con",
    "DVA_con",
]:
    path = [path for path in os.listdir(PATH) if form in path][0]
    path = os.path.join(PATH, path)

    with open(path, "r", encoding="latin-1") as f:
        doc = f.readlines()

    header, rows = doc[0].strip().split(";"), doc[1:]

    results = []
    for row in rows:
        row = row.strip().split(";")
        key_value = {key: value for key, value in zip(header, row)}
        if key_value["ORDEM_EXERC"] != "ÚLTIMO":
            continue

        unit = 1
        if key_value["ESCALA_MOEDA"] == "MIL":
            unit = 1000

        if form in ["BPA_con", "BPP_con"]:
            dict_row = {
                key: key_value[mapping[key]]
                for key in mapping
                if key != "ANALYSIS_START_PERIOD_DATE"
            }
        else:
            dict_row = {key: key_value[mapping[key]] for key in mapping}
            dict_row["ANALYSIS_START_PERIOD_DATE"] = datetime.strptime(
                dict_row["ANALYSIS_START_PERIOD_DATE"], "%Y-%m-%d"
            )

        dict_row["IS_FIXED_ACCOUNT"] = (
            True if dict_row["IS_FIXED_ACCOUNT"] == "S" else False
        )
        dict_row["ACCOUNT_VALUE"] = float(dict_row["ACCOUNT_VALUE"]) * unit
        dict_row["ANALYSIS_END_PERIOD_DATE"] = datetime.strptime(
            dict_row["ANALYSIS_END_PERIOD_DATE"], "%Y-%m-%d"
        )
        dict_row["REPORT_DATE"] = datetime.strptime(dict_row["REPORT_DATE"], "%Y-%m-%d")

        results.append(dict_row)

    df = pd.DataFrame(results)
    result_forms.append(df)

df = pd.concat(result_forms)

# %% [markdown]
# Criando base de dados

# %%
import sqlite3

database_path = "dfp_cvm.db"

with open(database_path, "w") as f:
    f.write("")

command = """CREATE TABLE IF NOT EXISTS DFP_CVM (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
	CNPJ TEXT NOT NULL,
	REPORT_DATE DATETIME NOT NULL,
	COMPANY_NAME TEXT NOT NULL,
	CVM_CODE TEXT NOT NULL,
	DFP_GROUP TEXT NOT NULL,
	VERSION TEXT NOT NULL,
	CURRENCY TEXT NOT NULL,
	ANALYSIS_START_PERIOD_DATE DATETIME,
	ANALYSIS_END_PERIOD_DATE DATETIME NOT NULL,
	ACCOUNT_NUMBER TEXT NOT NULL,
	ACCOUNT_NAME TEXT NOT NULL,
	ACCOUNT_VALUE FLOAT NOT NULL,
	IS_FIXED_ACCOUNT TEXT
)"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(database_path)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
cursor.executescript(command)

# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# Populando base de dados

# %%
queries = []

fields = list(mapping.keys())
fields_str = ", ".join(fields)
placeholders = ", ".join(["?"] * len(fields))

query = f"INSERT INTO DFP_CVM ({fields_str}) VALUES ({placeholders})"

data = []  # list of tuples to insert

for idx, row in df.iterrows():
    if len(row["ACCOUNT_NUMBER"].split(".")) > 3:
        continue

    row_values = []
    for field in fields:
        value = row[field]
        if isinstance(value, datetime):
            try:
                value = value.strftime("%Y-%m-%d")
            except Exception:
                value = "NULL"
        elif isinstance(value, float) and (value != value):  # NaN check
            value = None
        elif value == "NULL" or value == "":
            value = None
        row_values.append(value)

    data.append(tuple(row_values))

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(database_path)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
# Bulk insert safely
cursor.executemany(query, data)
# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# # Processamento Composição
#
# Carregando e limpando os dados

# %%
mapping = {
    "CNPJ": "CNPJ_CIA",
    "REPORT_DATE": "DT_REFER",
    "COMPANY_NAME": "DENOM_CIA",
    "VERSION": "VERSAO",
    "ORDINARY_SHARES_ISSUED": "QT_ACAO_ORDIN_CAP_INTEGR",
    "ORDINARY_SHARES_TREASURY": "QT_ACAO_ORDIN_TESOURO",
    "PREFERRED_SHARES_ISSUED": "QT_ACAO_PREF_CAP_INTEGR",
    "PREFERRED_SHARES_TREASURY": "QT_ACAO_PREF_TESOURO",
    "TOTAL_SHARES_ISSUED": "QT_ACAO_TOTAL_CAP_INTEGR",
    "TOTAL_SHARES_TREASURY": "QT_ACAO_TOTAL_TESOURO",
}

form = "composicao"
path = [path for path in os.listdir(PATH) if form in path][0]
path = os.path.join(PATH, path)

with open(path, "r", encoding="latin-1") as f:
    doc = f.readlines()

header, rows = doc[0].strip().split(";"), doc[1:]

results = []
for row in rows:
    row = row.strip().split(";")
    key_value = {key: value for key, value in zip(header, row)}

    dict_row = {key: key_value[mapping[key]] for key in mapping}
    dict_row["REPORT_DATE"] = datetime.strptime(dict_row["REPORT_DATE"], "%Y-%m-%d")
    dict_row["ORDINARY_SHARES_ISSUED"] = int(dict_row["ORDINARY_SHARES_ISSUED"])
    dict_row["ORDINARY_SHARES_TREASURY"] = int(dict_row["ORDINARY_SHARES_TREASURY"])
    dict_row["PREFERRED_SHARES_ISSUED"] = int(dict_row["PREFERRED_SHARES_ISSUED"])
    dict_row["PREFERRED_SHARES_TREASURY"] = int(dict_row["PREFERRED_SHARES_TREASURY"])
    dict_row["TOTAL_SHARES_ISSUED"] = int(dict_row["TOTAL_SHARES_ISSUED"])
    dict_row["TOTAL_SHARES_TREASURY"] = int(dict_row["TOTAL_SHARES_TREASURY"])

    results.append(dict_row)

df = pd.DataFrame(results)

# %% [markdown]
# Criando base de dados

# %%
command = """CREATE TABLE IF NOT EXISTS CVM_SHARE_COMPOSITION (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
	CNPJ TEXT NOT NULL,
    REPORT_DATE DATETIME NOT NULL,
    COMPANY_NAME TEXT NOT NULL,
    VERSION TEXT NOT NULL,
    ORDINARY_SHARES_ISSUED INTEGER NOT NULL,
    ORDINARY_SHARES_TREASURY INTEGER NOT NULL,
    PREFERRED_SHARES_ISSUED INTEGER NOT NULL,
    PREFERRED_SHARES_TREASURY INTEGER NOT NULL,
    TOTAL_SHARES_ISSUED INTEGER NOT NULL,
    TOTAL_SHARES_TREASURY INTEGER NOT NULL
)"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(database_path)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
cursor.executescript(command)

# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# Inserindo os dados

# %%
queries = []

fields = list(mapping.keys())
fields_str = ", ".join(fields)
placeholders = ", ".join(["?"] * len(fields))

query = f"INSERT INTO CVM_SHARE_COMPOSITION ({fields_str}) VALUES ({placeholders})"

data = []  # list of tuples to insert

for idx, row in df.iterrows():
    row_values = []
    for field in fields:
        value = row[field]
        if isinstance(value, datetime):
            value = value.strftime("%Y-%m-%d")
        row_values.append(value)

    data.append(tuple(row_values))

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(database_path)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
# Bulk insert safely
cursor.executemany(query, data)
# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %%
command = """SELECT DISTINCT ACCOUNT_NUMBER, ACCOUNT_NAME FROM DFP_CVM ORDER BY ACCOUNT_NUMBER"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(database_path)

# Create a cursor object using the connection
cursor = connection.cursor()

# Query the database
cursor.execute(command)

# Fetch column names
columns = (
    [description[0] for description in cursor.description] if cursor.description else []
)

# Fetch results
rows = cursor.fetchall()

# Close the cursor and connection
cursor.close()
connection.close()

# Format results as markdown table
if not rows:
    output = "No data found with given query"
else:
    # Create markdown table
    output = "| " + " | ".join(columns) + " |\n"
    output += "| " + " | ".join(["---" for _ in columns]) + " |\n"
    for row in rows:
        output += (
            "| "
            + " | ".join([str(cell) if cell is not None else "" for cell in row])
            + " |\n"
        )

print(output)
# Out:
# | ACCOUNT_NUMBER | ACCOUNT_NAME |
# | --- | --- |
# | 1 | Ativo Total |
# | 1.01 | Caixa e Equivalentes de Caixa |
# | 1.01 | Ativo Circulante |
# | 1.01.01 | Caixa |
# | 1.01.01 | Caixa e Equivalentes de Caixa |
# | 1.01.01 | Disponibilidades |
# | 1.01.02 | Aplicações de Liquidez |
# | 1.01.02 | Aplicações Financeiras |
# | 1.01.02 | Aplicações no mercado aberto |
# | 1.01.03 | Contas a Receber |
# | 1.01.03 | Ativos da Atividade Seguradora/Resseguradora |
# | 1.01.04 | Estoques |
# | 1.01.04 | Títulos e Créditos a Receber |
# | 1.01.05 | Ativos Biológicos |
# | 1.01.05 | Outros Valores e Bens |
# | 1.01.06 | Tributos a Recuperar |
# | 1.01.06 | Empréstimos e Depósitos Compulsórios |
# | 1.01.07 | Despesas Antecipadas |
# | 1.01.08 | Outros Ativos Circulantes |
# | 1.01.08 | Despesas de Comercialização Diferidas |
# | 1.01.09 | Outros Ativos Circulantes |
# | 1.02 | Ativos Financeiros |
# | 1.02 | Ativo Não Circulante |
# | 1.02.01 | Depósito Compulsório Banco Central |
# | 1.02.01 | Ativo Realizável a Longo Prazo |
# | 1.02.01 | Ativos Financeiros Avaliados a Valor Justo através do Resultado |
# | 1.02.02 | Ativos Financeiros Avaliados ao Valor Justo através do Resultado |
# | 1.02.02 | Investimentos |
# | 1.02.02 | Ativos Financeiros Avaliados a Valor Justo através de Outros Resultados Abrangentes |
# | 1.02.03 | Ativos Financeiros Avaliados ao Valor Justo através de Outros Resultados Abrangentes |
# | 1.02.03 | Imobilizado |
# | 1.02.03 | Ativos Financeiros Avaliados ao Custo Amortizado |
# | 1.02.04 | Ativos Financeiros ao Custo Amortizado |
# | 1.02.04 | Intangível |
# | 1.03 | Tributos |
# | 1.03 | Tributos Diferidos |
# | 1.03.01 | Imposto de Renda e Contribuição Social - Correntes |
# | 1.03.01 | Imposto de Renda e Contribuição Social Diferidos |
# | 1.03.01 | A Compensar |
# | 1.03.01 | Imposto de Renda e Contribuição Social - A Compensar |
# | 1.03.01 | Imposto de renda e contribuição social a recuperar |
# | 1.03.02 | Imposto de Renda e Contribuição Social - Diferidos |
# | 1.03.02 | Diferido |
# | 1.03.02 | Imposto de Renda e Contribuição Social - Diferido |
# | 1.03.02 | Imposto de Renda e Contribuição Social Diferidos |
# | 1.03.03 | Outros |
# | 1.03.03 | Outros impostos e contribuições a recuperar |
# | 1.04 | Outros Ativos |
# | 1.04.01 | Ativos Não Correntes a Venda |
# | 1.04.02 | Ativos de Operações Descontinuadas |
# | 1.04.03 | Outros |
# | 1.04.04 | Contratos de Seguro |
# | 1.04.04 | Investimentos mantidos para venda |
# | 1.04.05 | Depósitos judiciais |
# | 1.05 | Investimentos |
# | 1.05.01 | Participações em Coligadas |
# | 1.05.02 | Participações em Controladas em Conjunto |
# | 1.05.03 | Propriedades para Investimento |
# | 1.05.04 | Outros Investimentos |
# | 1.06 | Imobilizado |
# | 1.06.01 | Imobilizado de Uso |
# | 1.06.02 | Direito de Uso de Arrendamento |
# | 1.06.02 | Direito de Uso em Arrendamento |
# | 1.06.03 | Depreciação Acumulada |
# | 1.07 | Intangível |
# | 1.07.01 | Intangíveis |
# | 1.07.02 | Goodwill |
# | 1.07.03 | Amortização Acumulada |
# | 2 | Passivo Total |
# | 2.01 | Passivos Financeiros Avaliados ao Valor Justo através do Resultado |
# | 2.01 | Passivo Circulante |
# | 2.01 | Passivos Financeiros ao Valor Justo através do Resultado |
# | 2.01.01 | Obrigações Sociais e Trabalhistas |
# | 2.01.01 | Títulos e Valores Mobiliários |
# | 2.01.01 | Contas a Pagar |
# | 2.01.01 | Derivativos |
# | 2.01.01 | Instrumentos financeiros derivativos |
# | 2.01.01 | Obrigações por Emissões, Empréstimos e Repasses no Exterior |
# | 2.01.01 | Dívida Subordinada |
# | 2.01.02 | Fornecedores |
# | 2.01.02 | Derivativos |
# | 2.01.02 | Passivos da Atividade Seguradora/Resseguradora |
# | 2.01.02 | Notas Estruturadas |
# | 2.01.02 | Outros passivos financeiros |
# | 2.01.02 | Instrumentos Financeiros Derivativos |
# | 2.01.03 | Obrigações Fiscais |
# | 2.01.03 | Depósitos de Terceiros |
# | 2.01.03 | Outros Passivos Financeiros |
# | 2.01.04 | Empréstimos e Financiamentos |
# | 2.01.04 | Capitalização |
# | 2.01.05 | Outras Obrigações |
# | 2.01.05 | Outros Débitos |
# | 2.01.06 | Provisões |
# | 2.01.06 | Passivos sobre Ativos Não Correntes a Venda e Descontinuados |
# | 2.01.07 | Passivos sobre Ativos Não-Correntes a Venda e Descontinuados |
# | 2.02 | Passivos Financeiros ao Custo Amortizado |
# | 2.02 | Passivo Não Circulante |
# | 2.02 | Outros Passivos Financeiros Designados ao Valor Justo através do Resultado |
# | 2.02.01 | Depósitos |
# | 2.02.01 | Empréstimos e Financiamentos |
# | 2.02.01 | Passivo Exigível a Longo Prazo |
# | 2.02.02 | Captações no Mercado Aberto |
# | 2.02.02 | Outras Obrigações |
# | 2.02.03 | Recursos Mercado Interfinanceiro |
# | 2.02.03 | Tributos Diferidos |
# | 2.02.04 | Outras Captações |
# | 2.02.04 | Provisões |
# | 2.02.05 | Passivos sobre Ativos Não-Correntes a Venda e Descontinuados |
# | 2.02.06 | Lucros e Receitas a Apropriar |
# | 2.03 | Provisões |
# | 2.03 | Patrimônio Líquido Consolidado |
# | 2.03 | Passivos Financeiros ao Custo Amortizado |
# | 2.03.01 | Provisões trabalhistas, fiscais e cíveis |
# | 2.03.01 | Capital Social Realizado |
# | 2.03.01 | Provisões e contingências passivas |
# | 2.03.01 | Provisões para Outros Passivos |
# | 2.03.01 | Captações no mercado aberto |
# | 2.03.01 | Passivos com Instituições financeiras |
# | 2.03.01 | Depósitos de Clientes |
# | 2.03.01 | Provisão para Perda Esperada |
# | 2.03.01 | Depósitos |
# | 2.03.01 | Depósitos de clientes |
# | 2.03.01 | Provisões para Riscos Cíveis e Trabalhistas |
# | 2.03.01 | Provisões Cíveis, Fiscais e Trabalhistas |
# | 2.03.02 | Provisões para perdas esperadas com garantias prestadas e compromissos de empréstimos |
# | 2.03.02 | Reservas de Capital |
# | 2.03.02 | Depósitos |
# | 2.03.02 | Passivos com Clientes |
# | 2.03.02 | Depósitos de Instituições Financeiras |
# | 2.03.02 | Provisões Técnicas de Seguros e Previdências |
# | 2.03.02 | Captação no Mercado Aberto |
# | 2.03.02 | Obrigações por empréstimos ou de transferência de ativos financeiros |
# | 2.03.02 | Provisões para Compromissos e Outras Provisões |
# | 2.03.03 | Reservas de Reavaliação |
# | 2.03.03 | Recursos de aceites e emissão de títulos |
# | 2.03.03 | Títulos Emitidos |
# | 2.03.03 | Recursos de Emissão de Títulos |
# | 2.03.03 | Outras Provisões |
# | 2.03.03 | Recursos de Mercados Interbancários |
# | 2.03.03 | Obrigações por empréstimos e repasses |
# | 2.03.03 | Provisões para Riscos Fiscais |
# | 2.03.04 | Reservas de Lucros |
# | 2.03.04 | Obrigações por empréstimos, repasses e arrendamentos |
# | 2.03.04 | Empréstimos e Repasses |
# | 2.03.04 | Obrigações por Empréstimos |
# | 2.03.04 | Recursos de Mercados Institucionais |
# | 2.03.04 | Obrigações por títulos e valores mobiliários e letras financeiras |
# | 2.03.05 | Lucros/Prejuízos Acumulados |
# | 2.03.05 | Dívidas subordinadas e instrumentos de dívida elegíveis a capital |
# | 2.03.05 | Instrumentos Financeiros Derivativos |
# | 2.03.05 | Dívidas subordinadas |
# | 2.03.05 | Outros Passivos Financeiros |
# | 2.03.05 | Dívidas e letras financeiras subordinadas |
# | 2.03.06 | Ajustes de Avaliação Patrimonial |
# | 2.03.06 | Outros passivos financeiros |
# | 2.03.06 | Operações compromissadas |
# | 2.03.07 | Ajustes Acumulados de Conversão |
# | 2.03.07 | Outros passivos financeiros |
# | 2.03.08 | Outros Resultados Abrangentes |
# | 2.03.09 | Participação dos Acionistas Não Controladores |
# | 2.04 | Passivos Fiscais |
# | 2.04 | Provisões |
# | 2.04.01 | Obrigações fiscais e previdenciárias |
# | 2.04.01 | Correntes |
# | 2.04.01 | Passivos Fiscais Correntes |
# | 2.04.01 | Impostos Correntes |
# | 2.04.02 | Passivo fiscal diferido |
# | 2.04.02 | Diferidos |
# | 2.04.02 | Passivos Fiscais Diferidos |
# | 2.04.02 | Impostos Diferidos |
# | 2.05 | Outros Passivos |
# | 2.05 | Passivos Fiscais |
# | 2.05.01 | Fornecedores |
# | 2.05.01 | Correntes |
# | 2.05.01 | Imposto de Renda e Contribuição Social - Correntes |
# | 2.05.01 | Imposto de renda e contribuição social a r ecolher |
# | 2.05.01 | Obrigações de Arrendamento |
# | 2.05.02 | Negociação e intermediação de valores |
# | 2.05.02 | Diferidos |
# | 2.05.02 | Diferido |
# | 2.05.02 | Imposto de Renda e Contribuição Social - Diferidas |
# | 2.05.02 | Outros impostos e contribuições a recolher |
# | 2.05.02 | Outros Passivos e Obrigações |
# | 2.05.03 | Obrigações sociais e estatutárias |
# | 2.05.03 | Outras |
# | 2.05.04 | Provisões técnicas de previdência privada |
# | 2.05.05 | Outros Passivos |
# | 2.06 | Passivos sobre Ativos Não Correntes a Venda e Descontinuados |
# | 2.06 | Outros Passivos |
# | 2.06.01 | Passivos sobre Ativos Não Correntes a Venda |
# | 2.06.01 | Sociais e estatutárias |
# | 2.06.01 | Obrigações diversas |
# | 2.06.01 | Outros Passivos Financeiros |
# | 2.06.02 | Passivos sobre Ativos de Operações Descontinuadas |
# | 2.06.02 | Fiscais e previdenciárias |
# | 2.06.02 | Outros Passivos |
# | 2.06.02 | Provisão para Perda Esperada |
# | 2.06.03 | Obrigações fiscais diferidas |
# | 2.06.03 | Provisão para passivos contingentes |
# | 2.06.03 | Passivo de Planos de Capitalização |
# | 2.06.04 | Obrigações diversas |
# | 2.06.04 | Provisão de perda esperada decorrente de risco de crédito para avais e fianças |
# | 2.06.04 | Contratos de Seguro e Previdência Privada |
# | 2.06.05 | Provisão para passivos contingentes |
# | 2.06.05 | Obrigações Sociais e estatutárias |
# | 2.06.05 | Outros Passivos |
# | 2.07 | Patrimônio Líquido Consolidado |
# | 2.07 | Passivos sobre Ativos Não Correntes a Venda e Descontinuados |
# | 2.07.01 | Patrimônio Líquido Atribuído ao Controlador |
# | 2.07.01 | Passivos sobre Ativos Não Correntes a Venda |
# | 2.07.02 | Patrimônio Líquido Atribuído aos Não Controladores |
# | 2.07.02 | Passivos sobre Ativos de Operações Descontinuadas |
# | 2.08 | Patrimônio Líquido Consolidado |
# | 2.08.01 | Capital Social Realizado |
# | 2.08.02 | Reservas de Capital |
# | 2.08.03 | Reservas de Reavaliação |
# | 2.08.04 | Reservas de Lucros |
# | 2.08.05 | Lucros/Prejuízos Acumulados |
# | 2.08.06 | Ajustes de Avaliação Patrimonial |
# | 2.08.07 | Ajustes Acumulados de Conversão |
# | 2.08.08 | Outros Resultados Abrangentes |
# | 2.08.09 | Participação dos Acionistas Não Controladores |
# | 3.01 | Receitas de Intermediação Financeira |
# | 3.01 | Receita de Venda de Bens e/ou Serviços |
# | 3.01 | Receitas da Intermediação Financeira |
# | 3.01 | Receitas das Atividades Seguradoras/Resseguradoras |
# | 3.01.01 | Receita de Juros |
# | 3.01.01 | Receita operacional líquida |
# | 3.01.01 | Receita com prestação de serviços |
# | 3.01.01 | Receita Operacional bruta |
# | 3.01.01 | Receita bruta |
# | 3.01.01 | Receita de Incorporação de Imóveis |
# | 3.01.01 | Prêmios de seguros emitidos e contraprestações líquidas |
# | 3.01.01 | Receita de Venda de Bens e/ou Serviços |
# | 3.01.01 | Receita de infra, operação e manutenção, ganho de eficiência da implem da infra e outras, líquidas |
# | 3.01.01 | Receita de implementação de infraestrutura, O&M e outras, líquidas |
# | 3.01.01 | Receita de Serviços |
# | 3.01.01 | Receita operacional Liquida |
# | 3.01.01 | Receitas líquidas |
# | 3.01.01 | Receita líquida de vendas e serviços prestados |
# | 3.01.01 | Receita líquida de serviços prestados |
# | 3.01.01 | Transporte de Passageiros |
# | 3.01.01 | Receita Bruta de Vendas e/ou Serviços |
# | 3.01.01 | Receita Líquida |
# | 3.01.01 | Venda de Produtos e Serviços |
# | 3.01.01 | Receita de infra, correção monet, operação e manutenção, e outras, líquidas |
# | 3.01.01 | Receita Bruta de Vendas |
# | 3.01.01 | Receita Operacional Líquida |
# | 3.01.01 | Receita de operação e manutenção, Infraestrutura, Suprimento de Energia e Prestação de serviços |
# | 3.01.01 | Receita Operacional líquida |
# | 3.01.01 | Suprimento de energia elétrica |
# | 3.01.01 | Operações de crédito |
# | 3.01.01 | Receita venda de energia |
# | 3.01.01 | Transporte de passageiros |
# | 3.01.01 | Segmento Listado |
# | 3.01.01 | Receita líquida de vendas |
# | 3.01.01 | Receita líquida |
# | 3.01.01 | Receita Líquida da venda de Imóveis |
# | 3.01.01 | Receita líquida de contratos com clientes |
# | 3.01.01 | Aluguel de imóveis próprios |
# | 3.01.01 | Receita de aluguéis |
# | 3.01.01 | Operações de Crédito |
# | 3.01.01 | Serviços de Água |
# | 3.01.01 | Receitas com Seguros |
# | 3.01.01 | Receita bruta da prestação de serviços |
# | 3.01.01 | Receita líquida com venda de imóveis |
# | 3.01.01 | Receita com Juros de Similares |
# | 3.01.01 | Receita na infraestrutura, operação e manutenção, ganho de eficiência na implementação da infraestru |
# | 3.01.01 | Receita Líquida de Locações e Serviços |
# | 3.01.01 | Resultado líquido com instrumentos financeiros |
# | 3.01.01 | Receita de Venda de Bens e/ou Seviços |
# | 3.01.01 | Receita de Vendas de Bens e Serviços |
# | 3.01.01 | Receita líquida de vendas de mercadorias e serviços prestados |
# | 3.01.01 | Receita de seguro |
# | 3.01.01 | Vendas de Imóveis |
# | 3.01.01 | Receitas de prestação de serviços |
# | 3.01.01 | Softwares |
# | 3.01.01 | Contraprestações Líquidas/Prêmios Retidos |
# | 3.01.01 | Receita com Juros e Similares |
# | 3.01.01 | Receita de vendas e prestação de serviços do varejo automotivo |
# | 3.01.01 | Receita de Juros e Similares |
# | 3.01.01 | Receitas de Juros e Similares |
# | 3.01.01 | Venda bruta |
# | 3.01.01 | Receita de juros e rendimentos similares |
# | 3.01.01 | Receita líquida dos empreendimentos vendidos |
# | 3.01.01 | Incorporação e Revenda de Imoveis |
# | 3.01.01 | Receita de Venda e Serviços |
# | 3.01.01 | Mercado Interno |
# | 3.01.01 | Receita Operacional dos Produtos |
# | 3.01.01 | Receita Bruta |
# | 3.01.01 | Receita de Venda Líquida de Produtos |
# | 3.01.01 | Vendas brutas de produtos e serviços |
# | 3.01.01 | Receitas com Juros e Similares |
# | 3.01.01 | Suprimento de Energia Elétrica |
# | 3.01.01 | Receita líquida com vendas de mercadorias |
# | 3.01.01 | Receita liquida de incorporação imobiliária |
# | 3.01.01 | Venda de mercadorias |
# | 3.01.02 | Receita com renovação de frotas |
# | 3.01.02 | Impostos sobre a receita |
# | 3.01.02 | (-) Deduções da receita bruta |
# | 3.01.02 | (-) Prêmios de resseguros cedidos |
# | 3.01.02 | Receita de serviços de construção |
# | 3.01.02 | Remuneração dos ativos da concessão, líquidas |
# | 3.01.02 | Remuneração dos ativos da concessão, líquida |
# | 3.01.02 | Receita de Construção |
# | 3.01.02 | Receita de seguros |
# | 3.01.02 | Transporte de Cargas e Outros |
# | 3.01.02 | Devoluções/Descontos/Impostos s/ Vendas |
# | 3.01.02 | Movimentação de valor justo de ativos biológicos e produtos agrícolas |
# | 3.01.02 | Receita de Gestão de Fundos, Performance e ganhos (perdas) de capital |
# | 3.01.02 | Remuneração do ativo contrato de concessão |
# | 3.01.02 | Receita de prestação de serviços |
# | 3.01.02 | Remuneração finaceira do ativo de concessão |
# | 3.01.02 | Resultado de operações sujeitas a regime fiduciário e sem coobrigaçã |
# | 3.01.02 | Receita Carteira Trading - MTM |
# | 3.01.02 | Outras receitas |
# | 3.01.02 | Segmento Balcão |
# | 3.01.02 | Receita Líquida da Prestação de Serviços |
# | 3.01.02 | Taxa de administração |
# | 3.01.02 | Resultado de Operações com Títulos e Valores Mobiliários |
# | 3.01.02 | Serviços de Esgoto |
# | 3.01.02 | Receitas com Resseguros |
# | 3.01.02 | Contratos futuros de energia |
# | 3.01.02 | Descontos concedidos |
# | 3.01.02 | Marcação a mercado de instrumentos financeiros |
# | 3.01.02 | Resultado de Ativos Financeiros Mensurados ao Valor Justo por Meio do Resultado |
# | 3.01.02 | Receita Líquida de Venda de Imóveis |
# | 3.01.02 | Perdas esperadas decorrentes de risco de crédito |
# | 3.01.02 | Ajuste líquido ao Valor Justo do Ativos Biológicos |
# | 3.01.02 | Custos dos serviços prestados |
# | 3.01.02 | Carteira de Trading - MTM |
# | 3.01.02 | Receitas de prestação de serviços |
# | 3.01.02 | Ajuste a Valor Presente |
# | 3.01.02 | Vendas de Bens e Serviços |
# | 3.01.02 | Receita de serviços financeiros |
# | 3.01.02 | Ganhos / (Perdas) Líquidos de Operações de Câmbio |
# | 3.01.02 | Resultado de Ativos e Passivos Financeiros ao Valor Justo por meio do Resultado |
# | 3.01.02 | (-) IPI |
# | 3.01.02 | Deduções da Receita Bruta |
# | 3.01.02 | Impostos Incidentes Sobre Vendas |
# | 3.01.02 | Loteamento |
# | 3.01.02 | Mercado Externo |
# | 3.01.02 | Variação do valor justo dos ativos biológicos e do valor realizável líquido dos produtos agrícolas |
# | 3.01.02 | Receita de Venda Líquida de Serviços |
# | 3.01.02 | Impostos sobre vendas |
# | 3.01.02 | Resultado de Variação Cambial de Ativos e Passivos em Moeda Estrangeira |
# | 3.01.02 | Remuneração/Atualização do Ativo  Contratual |
# | 3.01.02 | Receita líquida com produtos e serviços financeiros |
# | 3.01.02 | Serviços prestados |
# | 3.01.03 | Deduções da receita bruta |
# | 3.01.03 | Impostos Sobre Vendas De Imóveis E Serviços |
# | 3.01.03 | Receitas de operações de crédito |
# | 3.01.03 | Impostos sobre Vendas |
# | 3.01.03 | Reversão de provisão (provisão) do valor recuperável de produtos agrícolas, líquida |
# | 3.01.03 | Dividendos |
# | 3.01.03 | Segmento Infraestrutura para Financiamento |
# | 3.01.03 | Deduções da Receita |
# | 3.01.03 | Resultado com Instrumentos Financeiros Derivativos |
# | 3.01.03 | Receita de Construção |
# | 3.01.03 | Operações de Previdência Complementar |
# | 3.01.03 | Impostos sobre o faturamento |
# | 3.01.03 | Custos de vendas de energia e serviços prestados |
# | 3.01.03 | Resultado de Ativos Financeiros Mensurados ao Valor Justo por Meio de Outros Resultados Abrangentes |
# | 3.01.03 | Impostos e outras deduções |
# | 3.01.03 | Variações cambiais líquidas |
# | 3.01.03 | Variação do Vaor Justo dos Ativos Biológicos e Produtos Agrícolas |
# | 3.01.03 | Taxa de Administração |
# | 3.01.03 | Variação das Provisões Técnicas |
# | 3.01.03 | Receita de vendas e prestação de serviços de outros negócios |
# | 3.01.03 | Ganhos / (Perdas) Líquidos de Ativos Financeiros ao VJORA |
# | 3.01.03 | Ajuste ao Valor Justo de Ativos e Passivos Financeiros |
# | 3.01.03 | (-)Devoluções e cancelamentos |
# | 3.01.03 | Abatimentos |
# | 3.01.03 | Locação |
# | 3.01.03 | Receita Setorial |
# | 3.01.03 | Ajuste ao Valor Justo de Ativo Biológico |
# | 3.01.03 | Receita de Locações |
# | 3.01.03 | Devoluções e descontos incondicionais |
# | 3.01.03 | Ganhos (Perdas) Líquidos com Ativos e Passivos Financeiros ao Valor Justo |
# | 3.01.03 | Receita de Operação e Manutenção |
# | 3.01.04 | Receitas de prestações de serviços |
# | 3.01.04 | Descontos Incorridos |
# | 3.01.04 | Ganho com venda de fazenda |
# | 3.01.04 | Segmento Tecnologia, Dados e Serviços |
# | 3.01.04 | Outras receitas |
# | 3.01.04 | Resultado de Operações de Câmbio |
# | 3.01.04 | Receita de Resíduo Sólido |
# | 3.01.04 | Operações de Capitalização |
# | 3.01.04 | Receita de prestação de serviços |
# | 3.01.04 | Aluguel de imóveis próprios |
# | 3.01.04 | Tributos Diretos de Operações com Planos de Assistência à Saúde da Operadora |
# | 3.01.04 | Ganhos / (Perda) Líquidos de Ativos e Passivos Financeiros ao valor justo por meio do resultado |
# | 3.01.04 | Resultado de Operações de Câmbio e Variação Cambial de Transações no Exterior |
# | 3.01.04 | (-) Impostos s/ vendas |
# | 3.01.04 | Prestação de Serviço e Outras |
# | 3.01.04 | Atualização Ativo Financeiro VNR |
# | 3.01.04 | Receita com construção da infraestrutura |
# | 3.01.05 | Contribuições de plano de previdência |
# | 3.01.05 | (Desvalorização) valorização no valor justo de investimentos |
# | 3.01.05 | Reversão de Provisões e Recuperação de Despesas |
# | 3.01.05 | Hospedagem |
# | 3.01.05 | Resultado das Aplicações Compulsórias |
# | 3.01.05 | Resultado de equivalência patrimonial de coligadas e controladas em conjunto |
# | 3.01.05 | Cancelamentos e Descontos |
# | 3.01.05 | Impostos sobre Vendas de Bens e Seviços |
# | 3.01.05 | Receitas de Prestação de Serviços e Tarifas Bancárias |
# | 3.01.05 | Dedução da Receita |
# | 3.01.05 | Disponibilização do Sistema de Transmissão |
# | 3.01.06 | Receita com títulos de capitalização |
# | 3.01.06 | Outros |
# | 3.01.06 | Impostos s/ Vendas |
# | 3.01.06 | Seguros |
# | 3.01.06 | Resultado de Contratos de Seguro e Previdência Privada |
# | 3.01.06 | Amortização Ativo Financeiro |
# | 3.01.07 | Receita de Seguro |
# | 3.01.07 | Receita de seguros (PAA) |
# | 3.01.07 | Outras Receitas |
# | 3.01.07 | Energia Elétrica de Curto Prazo |
# | 3.01.08 | Receita de seguros (BBA) |
# | 3.01.08 | Outras Receitas |
# | 3.01.09 | ICMS |
# | 3.01.10 | PIS e COFINS |
# | 3.01.11 | Quota RGR |
# | 3.01.12 | Outros Encargos |
# | 3.01.13 | Encargos Setoriais |
# | 3.01.14 | Encargos do Consumidor - P&D/MME/FNDCT |
# | 3.01.15 | Conta de Desenvolvimento Energético - CDE |
# | 3.01.16 | Taxa de Fiscalização do Serviço Público de Energia Elétrica - TFSEE |
# | 3.01.17 | Compensação Financeira pela Utilização de Recursos Hídricos - CFURH |
# | 3.01.18 | Outras deduções |
# | 3.01.19 | Compensação Financeira pela Utilização de Recursos Hídricos - CFURH |
# | 3.01.20 | Outras Receitas |
# | 3.02 | Despesas de Intermediação Financeira |
# | 3.02 | Custo dos Bens e/ou Serviços Vendidos |
# | 3.02 | Despesas da Intermediação Financeira |
# | 3.02 | Despesas da Atividade Seguradora/Resseguradora |
# | 3.02.01 | Despesa de Juros |
# | 3.02.01 | Energia comprada para revenda |
# | 3.02.01 | Custo com Energia Elétrica |
# | 3.02.01 | Custo com serviços prestados |
# | 3.02.01 | Custo De Incorporação E Venda De Imóveis |
# | 3.02.01 | Custo dos Bens e/ou Serviços Vendidos |
# | 3.02.01 | Custos com depreciação e amortização |
# | 3.02.01 | Custos operacionais |
# | 3.02.01 | Custo de Operação (Nota 30) |
# | 3.02.01 | Custo com energia elétrica |
# | 3.02.01 | Custo das vendas e serviços |
# | 3.02.01 | Custo de construção |
# | 3.02.01 | Custo dos Serviços Prestados |
# | 3.02.01 | Pessoal |
# | 3.02.01 | Custo dos Serviços de Implementação da Infraestrutura e Operação e Manutenção |
# | 3.02.01 | Custos do Serviços Prestados |
# | 3.02.01 | Energia elétrica comprada para revenda |
# | 3.02.01 | Custo de Serviços |
# | 3.02.01 | Custo do serviço de energia elétrica |
# | 3.02.01 | Custos dos Serviços Prestados |
# | 3.02.01 | Custos dos serviços prestados |
# | 3.02.01 | Custos com energia elétrica |
# | 3.02.01 | Custo dos Produtos Vendidos |
# | 3.02.01 | Custo de venda, locação e prestação de serviços e venda de ativos desmobilizados |
# | 3.02.01 | Custo com Pessoal |
# | 3.02.01 | Deduções da Receita Bruta |
# | 3.02.01 | Custo dos Imóveis Vendidos e dos Serviços Prestados |
# | 3.02.01 | Custo de Geração de energia elétrica |
# | 3.02.01 | Impostos e contribuições sobre a receita |
# | 3.02.01 | Despesa com emissão de CRI/CRA |
# | 3.02.01 | Custo dos Imóveis Vendidos |
# | 3.02.01 | PIS e COFINS |
# | 3.02.01 | Custo dos Lotes Vendidos |
# | 3.02.01 | Custo dos serviços prestados |
# | 3.02.01 | Cashback |
# | 3.02.01 | Custo dos Bens Vendidos |
# | 3.02.01 | Desenvolvimento e venda de lotes |
# | 3.02.01 | Custos com energia elétrica e gás |
# | 3.02.01 | Deduções PIS/COFINS |
# | 3.02.01 | Operações de Captação no Mercado |
# | 3.02.01 | Despesas com Serviços de Seguros |
# | 3.02.01 | ( - ) Custo das vendas, locações e prestação de serviços |
# | 3.02.01 | Custos de vendas de energia e serviços prestados |
# | 3.02.01 | Custo dos imóveis vendidos |
# | 3.02.01 | Despesa com Juros de Similares |
# | 3.02.01 | Custo das Locações |
# | 3.02.01 | Custos de incorporação e vendas imobiliárias |
# | 3.02.01 | Despesas administrativas |
# | 3.02.01 | Custos das mercadorias vendidas e dos serviços prestados |
# | 3.02.01 | Custo das mercadorias vendidas |
# | 3.02.01 | Despesas de seguro |
# | 3.02.01 | Com Venda de Imóveis |
# | 3.02.01 | Custos de aquisição |
# | 3.02.01 | Custo de Venda, Locação e Prestação de Serviços |
# | 3.02.01 | Custo de Softwares |
# | 3.02.01 | Variação do valor justo dos ativos biológicos |
# | 3.02.01 | Eventos/Sinistros Conhecidos ou Avisados |
# | 3.02.01 | Despesas com Juros e Similares |
# | 3.02.01 | Custo das vendas e serviços prestados do varejo automotivo |
# | 3.02.01 | Despesa de Juros e Similares |
# | 3.02.01 | Despesas de Juros e Similares |
# | 3.02.01 | CPV |
# | 3.02.01 | Despesa de juros e rendimentos similares |
# | 3.02.01 | Energia eletrica camprada para revenda |
# | 3.02.01 | Custo dos empreendimentos vendidos |
# | 3.02.01 | Dos imoveis Vendidos e Revendidos |
# | 3.02.01 | Variação Do Valor Justo Dos Ativos Biológicos |
# | 3.02.01 | Custo das Mercadorias Vendidas |
# | 3.02.01 | Custo dos Produtos |
# | 3.02.01 | Variação do Valor Justo dos Ativos Biológicos |
# | 3.02.01 | Custo das vendas com mercadorias |
# | 3.02.01 | Custo das mercadorias e produtos vendidos |
# | 3.02.01 | Custos de incorporação imobiliária |
# | 3.02.02 | Encargos sobre uso da rede elétrica |
# | 3.02.02 | Custo de Operação |
# | 3.02.02 | Custo com renovação de frotas |
# | 3.02.02 | Ajuste de Valor Justo - Ativo Biológico |
# | 3.02.02 | Prêmio de risco (repactuação do risco hidrológico) |
# | 3.02.02 | Custo de Operação - depreciação e amortização |
# | 3.02.02 | Variação do valor justo de ativos biológicos |
# | 3.02.02 | Serviços |
# | 3.02.02 | Custo dos Serviços de Construção |
# | 3.02.02 | Material |
# | 3.02.02 | Custo dos serviços prestados |
# | 3.02.02 | Custo de construção |
# | 3.02.02 | Custo de Construção |
# | 3.02.02 | Custo de operação |
# | 3.02.02 | Custo de produção de energia elétrica |
# | 3.02.02 | Despesa de seguros |
# | 3.02.02 | Custos de construção |
# | 3.02.02 | Subvenções para Investimentos Estaduais |
# | 3.02.02 | Custo de venda de ativos desmobilizados |
# | 3.02.02 | Compra de energia elétrica |
# | 3.02.02 | Custo dos imóveis vendidos |
# | 3.02.02 | Variação no valor justo de ativo biológico |
# | 3.02.02 | Custos das mercadorias vendidas |
# | 3.02.02 | Depreciação e amortização |
# | 3.02.02 | Depreciação e Amortização |
# | 3.02.02 | Valor justo na compra e venda de energia |
# | 3.02.02 | Impostos sobre Serviços |
# | 3.02.02 | Custo dos Serviços Prestados |
# | 3.02.02 | Gerais e Administrativas |
# | 3.02.02 | Variação do Valor Justo dos Ativos Biológicos |
# | 3.02.02 | Custos de construção de infraestrutura |
# | 3.02.02 | Operações de Empréstimos e Repasses |
# | 3.02.02 | Custo de ociosidade |
# | 3.02.02 | Despesas Líquidas com Contratos de Resseguros/Retrocessões |
# | 3.02.02 | ( - ) Custo de venda de ativos desmobilizados |
# | 3.02.02 | Custo com operação |
# | 3.02.02 | Custo dos Imóveis Vendidos |
# | 3.02.02 | Outros custos |
# | 3.02.02 | Despesas com pessoal |
# | 3.02.02 | Custos de Construção |
# | 3.02.02 | Custos de aquisição - outros |
# | 3.02.02 | Com Aluguel de Imóveis |
# | 3.02.02 | Custos dos serviços prestados |
# | 3.02.02 | Custo de Venda de Ativos Desmobilizados |
# | 3.02.02 | Custo de produtos de crédito |
# | 3.02.02 | Custo dos produtos vendidos |
# | 3.02.02 | Encargos Sociais sobre Serviços |
# | 3.02.02 | Perda Esperada de Empréstimos e Adiantamentos a Clientes |
# | 3.02.02 | Custo de serviços financeiros |
# | 3.02.02 | (Perda) Esperada com Operações de Crédito e Arrendamento Mercantil Financeiro |
# | 3.02.02 | Encargo de uso do sistema de transmissão e distribuilção |
# | 3.02.02 | Loteamento |
# | 3.02.02 | Custos Dos Produtos Vendidos |
# | 3.02.02 | Custo dos Produtos Vendidos |
# | 3.02.02 | Custo de Ociosidade |
# | 3.02.02 | Realização do valor justo dos ativos biológicos |
# | 3.02.02 | Custo dos produtos e serviços financeiros |
# | 3.02.03 | Combustível para produção de energia elétrica |
# | 3.02.03 | Custo do Serviços Prestados a Terceiros |
# | 3.02.03 | Custos com pessoal |
# | 3.02.03 | Custo de Operação - Outros |
# | 3.02.03 | Custo da outorga |
# | 3.02.03 | Serviços de terceiros |
# | 3.02.03 | Custo da operação |
# | 3.02.03 | Custo de construção da infraestrutura de concessão |
# | 3.02.03 | Custo de operação |
# | 3.02.03 | Custos de operação |
# | 3.02.03 | Custo de construção |
# | 3.02.03 | Depreciação e Amortização |
# | 3.02.03 | Custos dos imóveis vendidos |
# | 3.02.03 | Depreciação e amortização |
# | 3.02.03 | Serviços de Terceiros |
# | 3.02.03 | Custo dos serviços prestados |
# | 3.02.03 | Outros custos com operação |
# | 3.02.03 | Custo de Operação |
# | 3.02.03 | Pessoal |
# | 3.02.03 | Provisão para Perdas Esperadas Associadas ao Risco de Crédito |
# | 3.02.03 | Operações de Previdência Complementar |
# | 3.02.03 | Repactuação do risco hidrológico |
# | 3.02.03 | Despesas tributárias |
# | 3.02.03 | Custos dos serviços prestados |
# | 3.02.03 | Custo de venda, locação e prestação de serviços e venda de ativos desmobilizados |
# | 3.02.03 | Materiais Odontológicos |
# | 3.02.03 | Perda Esperada com Demais Ativos Financeiros |
# | 3.02.03 | Perdas esperadas em créditos de serviços financeiros |
# | 3.02.03 | (Perda) Esperada com demais Ativos Financeiros, líquida |
# | 3.02.03 | Dos Imoveis Locados e Serviços |
# | 3.02.03 | Custo dos Serviços Prestados |
# | 3.02.04 | Construção |
# | 3.02.04 | Custo com revenda de Gás |
# | 3.02.04 | Custos com manutenção |
# | 3.02.04 | Custo do serviço prestado a terceiros |
# | 3.02.04 | Depreciação e amortização |
# | 3.02.04 | Energia comprada |
# | 3.02.04 | Custo de serviço prestado a terceiros |
# | 3.02.04 | Serviços |
# | 3.02.04 | Utilização do bem público - UBP |
# | 3.02.04 | Depreciação e Amortização |
# | 3.02.04 | Custo do Serviço Prestado a Terceiros |
# | 3.02.04 | Encargos de uso do sistema de distribuição |
# | 3.02.04 | Comerciais e de marketing |
# | 3.02.04 | Operações de Capitalização |
# | 3.02.04 | Outros |
# | 3.02.04 | Demais Custos Operacionais |
# | 3.02.04 | (Despesas) / Recuperação de Sinistros |
# | 3.02.04 | Material |
# | 3.02.04 | Custo de Construção |
# | 3.02.05 | Pessoal, Material e Serviço |
# | 3.02.05 | Pessoal, materiais e serviços |
# | 3.02.05 | Tarifa de uso dos sistemas elétricos de distribuição (TUSD) |
# | 3.02.05 | Custo com pessoal |
# | 3.02.05 | Contratos futuros de energia |
# | 3.02.05 | Materiais, Equipamentos e Veículos |
# | 3.02.05 | Outros custos operacionais |
# | 3.02.05 | Custo dos Serviços Prestados |
# | 3.02.05 | Custo com compra de energia |
# | 3.02.05 | Softwares |
# | 3.02.05 | Custo de construção |
# | 3.02.05 | Variação da Provisão de Eventos/Sinistros Ocorridos e Não Avisados (PEONA) |
# | 3.02.05 | Serviços de terceiro |
# | 3.02.06 | Depreciação |
# | 3.02.06 | Custos com seguros |
# | 3.02.06 | Provisão de manutenção |
# | 3.02.06 | Depreciação e amortização |
# | 3.02.06 | Energia Elétrica |
# | 3.02.06 | Custo de Infraestrutura |
# | 3.02.06 | Compromissos futuros marcação a mercado |
# | 3.02.06 | Serviços de terceiros |
# | 3.02.06 | Sinistros |
# | 3.02.07 | Amortização |
# | 3.02.07 | Custos com operação |
# | 3.02.07 | Materiais, equipamentos e veículos |
# | 3.02.07 | Encargos de uso da rede elétrica |
# | 3.02.07 | Seguros |
# | 3.02.07 | Depreciação e Amortização |
# | 3.02.07 | Depreciação e amortização |
# | 3.02.07 | Reservas Técnicas de Sinistros |
# | 3.02.07 | Arrendamento e aluguéis |
# | 3.02.08 | Outros |
# | 3.02.08 | Taxas setoriais |
# | 3.02.08 | Compensação financeira pela utilização dos recursos hídricos (CFURH) |
# | 3.02.08 | Provisões de IPTU |
# | 3.02.08 | Outras despesas/receitas operacionais |
# | 3.02.08 | Despesas de seguros |
# | 3.02.08 | Seguros |
# | 3.02.09 | Custos com meio ambiente |
# | 3.02.09 | Custo de obras |
# | 3.02.09 | Taxa de fiscalização dos serviços de energia elétrica (TFSEE) |
# | 3.02.09 | Outros |
# | 3.02.09 | Ajuste a valor justo de earn-out a pagar e de opção de compra |
# | 3.02.09 | Tributos |
# | 3.02.10 | Outros custos |
# | 3.02.10 | Seguros |
# | 3.02.10 | Redução ao valor recuperável de ativos |
# | 3.02.10 | (-) Recuperação de despesas |
# | 3.02.11 | Aluguéis |
# | 3.02.11 | Subvenção CCC |
# | 3.02.12 | Provisões para riscos |
# | 3.02.12 | (Reversões) / constituições de provisões para riscos |
# | 3.02.12 | Custo de construção |
# | 3.02.13 | Reversão estimada para créditos de liquidação duvidosa (PECLD) |
# | 3.02.13 | Perdas estimadas para créditos de liquidação duvidosa (PECLD) |
# | 3.02.13 | Materia-prima e insumos p/ prod energia eletrica |
# | 3.02.14 | Recuperação de custos de compra de energia pela extensão da concessão (acordo GSF) |
# | 3.02.14 | Provisão para contingências |
# | 3.02.15 | Outros |
# | 3.03 | Resultado Bruto de Intermediação Financeira |
# | 3.03 | Resultado Bruto |
# | 3.03 | Resultado Bruto Intermediação Financeira |
# | 3.04 | Outras Despesas e Receitas Operacionais |
# | 3.04 | Despesas/Receitas Operacionais |
# | 3.04 | Outras Despesas/Receitas Operacionais |
# | 3.04 | Despesas Administrativas |
# | 3.04.01 | Despesa de Provisão para Perda Esperada para Risco de Crédito |
# | 3.04.01 | Despesas com Vendas |
# | 3.04.01 | Receitas de Prestação de Serviços |
# | 3.04.01 | Despesas com Pessoal Próprio |
# | 3.04.02 | Receitas de Prestação de Serviços |
# | 3.04.02 | Despesas Gerais e Administrativas |
# | 3.04.02 | Despesas de Pessoal |
# | 3.04.02 | Despesas com Serviços de Terceiros |
# | 3.04.03 | Despesas com Pessoal |
# | 3.04.03 | Perdas pela Não Recuperabilidade de Ativos |
# | 3.04.03 | Outras Despesas Administrativas |
# | 3.04.03 | Despesas com Localização e Funcionamento |
# | 3.04.04 | Outras Despesas de Administrativas |
# | 3.04.04 | Outras Receitas Operacionais |
# | 3.04.04 | Despesas Tributárias |
# | 3.04.04 | Despesas com Publicidade e Propaganda |
# | 3.04.05 | Despesas Tributárias |
# | 3.04.05 | Outras Despesas Operacionais |
# | 3.04.05 | Outras Receitas Operacionais |
# | 3.04.05 | Despesas com Tributos |
# | 3.04.06 | Outras Receitas Operacionais |
# | 3.04.06 | Resultado de Equivalência Patrimonial |
# | 3.04.06 | Outras Despesas Operacionais |
# | 3.04.06 | Despesas com Publicações |
# | 3.04.07 | Outras Despesas Operacionais |
# | 3.04.07 | Resultado da Equivalência Patrimonial |
# | 3.04.07 | Despesas com Donativos e Contribuições |
# | 3.04.08 | Resultado da Equivalência Patrimonial |
# | 3.04.08 | Outras Despesas Administrativas |
# | 3.05 | Resultado antes dos Tributos sobre o Lucro |
# | 3.05 | Resultado Antes do Resultado Financeiro e dos Tributos |
# | 3.05 | Resultado Antes dos Tributos sobre o Lucro |
# | 3.05 | Outras Receitas e Despesas Operacionais |
# | 3.05.01 | Receitas de Comissões |
# | 3.05.02 | Custo dos serviços prestados |
# | 3.06 | Imposto de Renda e Contribuição Social sobre o Lucro |
# | 3.06 | Resultado Financeiro |
# | 3.06 | Resultado de Equivalência Patrimonial |
# | 3.06.01 | Corrente |
# | 3.06.01 | Receitas Financeiras |
# | 3.06.01 | Receitas de Equivalência Patrimonial |
# | 3.06.02 | Diferido |
# | 3.06.02 | Despesas Financeiras |
# | 3.06.02 | Despesas de Equivalência Patrimonial |
# | 3.07 | Lucro ou Prejuízo das Operações Continuadas |
# | 3.07 | Resultado Antes dos Tributos sobre o Lucro |
# | 3.07 | Resultado Líquido das Operações Continuadas |
# | 3.07 | Resultado Antes do Resultado Financeiro e dos Tributos |
# | 3.08 | Resultado Líquido das Operações Descontinuadas |
# | 3.08 | Imposto de Renda e Contribuição Social sobre o Lucro |
# | 3.08 | Resultado Financeiro |
# | 3.08.01 | Corrente |
# | 3.08.01 | Lucro/Prejuízo Líquido das Operações Descontinuadas |
# | 3.08.01 | Receitas Financeiras |
# | 3.08.02 | Diferido |
# | 3.08.02 | Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas |
# | 3.08.02 | Despesas Financeiras |
# | 3.08.03 | Resultado Financeiro Líquido de Seguros/Resseguros/Retrocessões |
# | 3.09 | Lucro ou Prejuízo antes das Participações e Contribuições Estatutárias |
# | 3.09 | Resultado Líquido das Operações Continuadas |
# | 3.09 | Lucro/Prejuízo Consolidado do Período |
# | 3.09 | Resultado Antes dos Tributos sobre o Lucro |
# | 3.09.01 | Atribuído a Sócios da Empresa Controladora |
# | 3.09.02 | Atribuído a Sócios Não Controladores |
# | 3.10 | Participações nos Lucros e Contribuições Estatutárias |
# | 3.10 | Resultado Líquido de Operações Descontinuadas |
# | 3.10 | Imposto de Renda e Contribuição Social sobre o Lucro |
# | 3.10.01 | Lucro/Prejuízo Líquido das Operações Descontinuadas |
# | 3.10.01 | Corrente |
# | 3.10.02 | Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas |
# | 3.10.02 | Diferido |
# | 3.11 | Lucro ou Prejuízo Líquido Consolidado do Período |
# | 3.11 | Lucro/Prejuízo Consolidado do Período |
# | 3.11 | Resultado Líquido das Operações Continuadas |
# | 3.11.01 | Atribuído aos Sócios da Empresa Controladora |
# | 3.11.01 | Atribuído a Sócios da Empresa Controladora |
# | 3.11.02 | Atribuído aos Sócios não Controladores |
# | 3.11.02 | Atribuído a Sócios Não Controladores |
# | 3.12 | Resultado Líquido de Operações Descontinuadas |
# | 3.12.01 | Lucro/Prejuízo Líquido das Operações Descontinuadas |
# | 3.12.02 | Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas |
# | 3.13 | Lucro/Prejuízo Consolidado do Período |
# | 3.13.01 | Atribuído a Sócios da Empresa Controladora |
# | 3.13.02 | Atribuído a Sócios Não Controladores |
# | 3.99 | Lucro por Ação (R$/Ação) |
# | 3.99 | Lucro por Ação - (Reais / Ação) |
# | 3.99 | Lucro por Ação - (R$ / Ação) |
# | 3.99.01 | Lucro Básico por Ação |
# | 3.99.02 | Lucro Diluído por Ação |
# | 4.01 | Lucro ou Prejuízo Líquido do Período |
# | 4.01 | Lucro Líquido Consolidado do Período |
# | 4.02 | Outros Resultados Abrangentes Próprios |
# | 4.02 | Outros Resultados Abrangentes |
# | 4.02.01 | Valores que serão Reclassificados para o Resultado |
# | 4.02.01 | Mudança no valor justo dos instrumentos financeiros por meio de ORA |
# | 4.02.01 | Ganho (Perda) com Plano de Benefício Definido |
# | 4.02.01 | Remensuração de obrigações deplanos de benefícios definidos - pós emprego |
# | 4.02.01 | Remensuração da obrigação com previdência privada |
# | 4.02.01 | Ajuste ganhos e perdas atuariais |
# | 4.02.01 | Hedge de fluxo de caixa |
# | 4.02.01 | Ajustes de Avaliação Patrimonial Aplicações Financeiras |
# | 4.02.01 | Itens que não serão reclassificados para a demonstração do resultado |
# | 4.02.01 | Variação cambial de investida no exterior |
# | 4.02.01 | Variação Cambial sobre Investimentos no Exterior |
# | 4.02.01 | Efeito dos planos de benefício e planos de saúde a empregados das investidas |
# | 4.02.01 | Ganho (Perda) Atuarial com Benefícios Pós emprego |
# | 4.02.01 | Variação cambial de operações localizadas no exterior |
# | 4.02.01 | Ganhos (Perdas) na Conversão de Operações no Exterior |
# | 4.02.01 | Valor financeiro mensurado a valor justo |
# | 4.02.01 | Perda de passivo atuarial ( líquido de impostos) |
# | 4.02.01 | Realização da reserva de reavaliação, líquida dos efeitos tributários |
# | 4.02.01 | Ganho (perda) de valor justo de instrumentos de hedge durante o exercício |
# | 4.02.01 | Ajustes ganhos e perdas atuariais |
# | 4.02.01 | Perdas (ganhos) com Instrumentos Financeiros Derivativos |
# | 4.02.01 | Ajustes de títulos e valores mobiliários |
# | 4.02.01 | Ganhos/Perdas de capital s/ coligadas |
# | 4.02.01 | Ajuste de Avaliação Atuarial |
# | 4.02.01 | Hedge de Fluxo de Caixa |
# | 4.02.01 | Diferenças cambiais de conversão de operações no exterior |
# | 4.02.01 | Plano de pensão e outros benefícios pós emprego |
# | 4.02.01 | Ganhos (Perdas) atuariais, líquidos dos efeitos tributários |
# | 4.02.01 | Remensuração de obrigações com aposentadoria |
# | 4.02.01 | Ganhos (Perdas) com Instrumentos Financeiros Derivativos |
# | 4.02.01 | Ajustes de participação no capital de controladas/coligadas |
# | 4.02.01 | Plano de pensão e outros benefícios pós-emprego |
# | 4.02.01 | Resultado de operações descontinuadas |
# | 4.02.01 | Assistencia médica complementar |
# | 4.02.01 | Ajuste patrimonial - plano de pensão |
# | 4.02.01 | Variação cambial na conversão de operações no exterior |
# | 4.02.01 | Ajuste Acumulado de Conversão e Variação Cambial em Controladas |
# | 4.02.01 | Hedge de Fluxos de Caixa - Parcela Efetiva das Mudanças no Valor Justo |
# | 4.02.01 | Projeção a partir da revisão das premissas econômicas do plano de pensão |
# | 4.02.01 | Benefício pós emprego - superávit (déficit) atuarial |
# | 4.02.01 | Reserva de reavaliação reflexa |
# | 4.02.01 | Resultados abrangentes (hedge e benefícios pós-emprego, líquidos de tributos diferidos) |
# | 4.02.01 | Instrumentos financeiros de proteção - NDF |
# | 4.02.01 | Perda sobre passivos atuariais, líquido dos efeitos fiscais |
# | 4.02.01 | Outros resultados abrangentes:  - Ajuste de conversão |
# | 4.02.01 | Variação Cambial sobre Investimentos |
# | 4.02.01 | Ganhos atuariais |
# | 4.02.01 | Ganhos e (perdas) atuariais - Benefícios pós-emprego |
# | 4.02.01 | Diferença de câmbio na conversão de operações no exterior |
# | 4.02.01 | Opção de venda concedida a não controladores |
# | 4.02.01 | Ganho sobre hedge de fluxo de caixa |
# | 4.02.01 | Ajustes de Passivos Atuariais - não serão reclassificados para o resultado |
# | 4.02.01 | Ajustes Acumulados de Conversão |
# | 4.02.01 | Ajustes acumulado de conversão |
# | 4.02.01 | Ajuste de Valor Justo - Propriedade para Investimento |
# | 4.02.01 | Ajuste de conversão de balanço |
# | 4.02.01 | Hedges de Fluxo de Caixa |
# | 4.02.01 | Ganho não realizada com instrumentos patrimoniais designados ao valor justo por meio de outros resul |
# | 4.02.01 | Remensuração de obrigações de planos de benefícios definidos |
# | 4.02.01 | Efeito de conversão de moeda estrangeira |
# | 4.02.01 | Ganho (perda) na atualização do plano de benefício |
# | 4.02.01 | Ganhos (Perdas) em Operações de Hedge de Fluxo de Caixa |
# | 4.02.01 | Diferenças cambiais na conversão de operações no exterior |
# | 4.02.01 | Perdas de hedge de fluxo de caixa |
# | 4.02.01 | Ganhos (perdas) na Conversão de Operações no Exterior |
# | 4.02.01 | Ganhos/Perdas na conversão de demonstrações financeiras |
# | 4.02.01 | Efeito na conversão de investimentos no exterior |
# | 4.02.01 | Remensuração de obrigações de benefícios pós-emprego, líquido dos impostos |
# | 4.02.01 | Valor justo de derivativos |
# | 4.02.01 | Mudança no valor justo do hedge fluxo de caixa, líquido de impostos |
# | 4.02.01 | Ajuste de avaliação patrimonial de instrumentos financeiros derivativos |
# | 4.02.01 | Ajuste de avaliação patrimonial - Perdas atuariais |
# | 4.02.01 | Resultado conversão de moeda estrangeira (CTA) |
# | 4.02.01 | Operações de hedge accounting |
# | 4.02.01 | Ajustes de Conversão |
# | 4.02.01 | Ajustes de Conversão de Moedas |
# | 4.02.01 | Ganho líquido originado de reavaliação de ativos financeiros no exercício |
# | 4.02.01 | Ganhos (perdas) atuariais, líquidos dos efeitos tributários |
# | 4.02.01 | Ajustes acumulados de conversão |
# | 4.02.01 | Ajustes de Avaliação Patrimonial |
# | 4.02.01 | Transações com sócios |
# | 4.02.01 | Valor Justo de Derivativos |
# | 4.02.01 | Perdas atuariais com planos de pensão, líquidos de impostos diferidos |
# | 4.02.01 | Efeito de Mudança na Participação Relativa em Controlada em Conjunto |
# | 4.02.01 | Efeitos cambiais sobre conversão de investimento no exterior |
# | 4.02.01 | Benefício pós-emprego |
# | 4.02.01 | Variação Cambial sobre Investimento em Controlada no Exterior |
# | 4.02.01 | Ajuste acumulado de conversão |
# | 4.02.01 | Variação cambial de investidas localizadas no exterior |
# | 4.02.01 | Ganhos (perdas) na conversão de operações no exterior |
# | 4.02.01 | Ajuste ao valor justo contra o patrimônio líquido |
# | 4.02.01 | Ganho ( perda) sobre hedge |
# | 4.02.01 | Outros resultados abrangentes |
# | 4.02.01 | Hedge de fluxo de caixa - parcela efetiva das mudanças no valor justo |
# | 4.02.01 | Ajuste de avaliação patrimonial |
# | 4.02.01 | Diferenças cambiais de conversão de controladas no exterior |
# | 4.02.01 | Ajuste de Avaliação Patrimonial |
# | 4.02.01 | Efeito na conversão de investimentos em moeda estrangeira |
# | 4.02.01 | Hedge Fluxo de caixa |
# | 4.02.01 | Ajuste Acumulado de Conversão |
# | 4.02.01 | Instrumentos financeiros derivativos - Hedge |
# | 4.02.01 | Ajuste de conversão de moeda de controladas no exterior |
# | 4.02.01 | Baixa do valor de venda de participação societária (nota 14.d) |
# | 4.02.01 | Realização do custo atribuído |
# | 4.02.01 | Efeito Cambial na Conversão das Demonstrações Financeiras e sobre os Investimentos no Exterior |
# | 4.02.01 | Diferenças Cambiais Sobre Conversão de Operações |
# | 4.02.01 | Ajustes de Instrumentos Financeiros  |
# | 4.02.01 | Hedge de fluxos de caixa |
# | 4.02.01 | Equivalência patrimonial sobre outro resultado abrangente em controlada e controlada em conjunto |
# | 4.02.01 | Ganho (perda) Atuarial com Benefícios de Aposentadoria |
# | 4.02.01 | Ajustes de Conversão de Balanço de Controladas no Exterior (operações continuadas) |
# | 4.02.01 | Ganhos/(perdas) sobre instrumentos financeiros |
# | 4.02.01 | Prejuízo do exercício |
# | 4.02.01 | Transações de capital, líquidos dos efeitos tributários |
# | 4.02.01 | Atualização do passivo atuarial |
# | 4.02.01 | Variação do valor justo dos ativos financeiros |
# | 4.02.01 | Resultado com hedge de fluxo de caixa da Controladora |
# | 4.02.01 | Ganhos atuariais de plano de benefícios definido |
# | 4.02.01 | Ajustes de avaliação patrimonial reflexo |
# | 4.02.01 | Ganho (Perda) Plano de benefício definido |
# | 4.02.01 | Ganhos s/ hedge de fluxo de caixa - parcela efet. das mudanças de valor justo - líq. de impostos |
# | 4.02.01 | Obrigações com benefícios pós-emprego - Companhia |
# | 4.02.01 | Ajustes de Conversão de Investimentos no Exterior |
# | 4.02.01 | (Prejuízo) líquido do exercício |
# | 4.02.01 | Instrumentos financeiros derivativos, líquido dos efeitos tributários |
# | 4.02.01 | Variação de ajuste de avaliação patrimonial de ativos financeiros disponíveis para venda |
# | 4.02.01 | Ganho (perda) na conversão das demonstrações financeiras de controladas no exterior |
# | 4.02.01 | Ganhos (perdas) atuariais com planos de benefícios definidos |
# | 4.02.01 | Ajustes de conversão do período |
# | 4.02.01 | Ganhos atuariais plano de benefício definido reflexo de invest. em subsidiárias, líquidos de imposto |
# | 4.02.01 | Realização da Reserva de Reavaliação |
# | 4.02.01 | Ajustes de Avaliação de Instr. Financ. Líquido de Imposto de IR e CS |
# | 4.02.01 | Ajustes de conversão de câmbio de operação no exterior |
# | 4.02.01 | Ativos Financeiros por meio de outros resultados abrangentes |
# | 4.02.01 | Ganho (perda) atuarial, líquido |
# | 4.02.01 | Ganhos (perdas) atuariais sobre provisão pós-emprego |
# | 4.02.01 | Participação no resultado abrangente de investidas |
# | 4.02.01 | Ajustes acumulados de conversão de moedas |
# | 4.02.01 | Ganhos atuariais líquidas não realizadas com plano de pensão de benefício definido |
# | 4.02.01 | Ajuste de conversão de investimentos no exterior |
# | 4.02.01 | Ganhos (perdas) atuariais - plano de pensão e saúde |
# | 4.02.01 | Ganho (perda) de valor justo de instrumentos de hedge durante o exercício - líquido de impostos |
# | 4.02.01 | Realização do ajuste de avaliação patrimonial |
# | 4.02.01 | Equivalência patrimonial sobre hedge de fluxo de caixa de controlada |
# | 4.02.01 | Efeitos de conversão de moeda estrangeira |
# | 4.02.01 | Parcela originada da cisão |
# | 4.02.01 | Ajustes de hiperinflação de investimentos na Argentina/CTI |
# | 4.02.01 | Derivativos - hedge de fluxo de caixa nas controladas |
# | 4.02.01 | Instrumentos financeiros derivativos - ganhos (perdas) excluído do P.L e incluído no resultado |
# | 4.02.01 | Variação cambial sobre investimentos no exterior |
# | 4.02.01 | Valor justo de hedge de fluxo de caixa, líquido de impostos |
# | 4.02.01 | Ajustes de conversão operações no exterior |
# | 4.02.01 | Realização ajuste avaliação patrimonial |
# | 4.02.01 | Ativos Financeiros ao valor justo por meio de outros resultados abrangentes |
# | 4.02.01 | Valor justo de instrumentos financeiros de Hedge, líquido de impostos |
# | 4.02.01 | Ganhos e (Perdas) Atuariais sobre Planos de Benefícios Definidos |
# | 4.02.01 | Ganho (Perda) com hedge de fluxo de caixa |
# | 4.02.01 | Resultado com Derivativos |
# | 4.02.01 | Efeito da conversão de moeda estrangeira |
# | 4.02.01 | Ajuste ao valor justo de Instrumentos financeiros derivativos |
# | 4.02.01 | Reversão dos Dividendos não reclamados |
# | 4.02.01 | Resultado financeiro líquido de contratos de seguro e resseguro |
# | 4.02.01 | Plano de benefício definido |
# | 4.02.01 | Ativos Financeiros Disponiveis para Venda |
# | 4.02.01 | Outros resultados abrangentes reflexo sobre coligada |
# | 4.02.01 | Ativos Financeiros Disponíveis para Venda |
# | 4.02.01 | Diferenças cambiais de conversão de operações no exterior - CTA |
# | 4.02.01 | Baixa de ajuste de avaliação patrimonial pelo encerramento de investida |
# | 4.02.01 | Ganhos e perdas atuariais - controladas |
# | 4.02.01 | Derivativos de mercadorias - Futuro, opções e contratos a termo |
# | 4.02.01 | Ajustes de conversão em controlada no exterior |
# | 4.02.01 | Ganhos sobre Hedge de Fluxo de Caixa |
# | 4.02.01 | Ajuste acumulado de conversão de moeda estrangeira |
# | 4.02.01 | Outros Resultados Abrangentes |
# | 4.02.01 | Ajuste Acumulado de Conversão em Controladas |
# | 4.02.01 | Valores que serão reclassificados para o resultado |
# | 4.02.01 | Ganho (perda) na conversão de demonstrações financeiras de controlada no exterior |
# | 4.02.01 | Valor justo decorrente de combinação de negócios |
# | 4.02.01 | Hedge fluxo de caixa - Receita Exportação ACC/PPE |
# | 4.02.01 | Ajuste de conversão do período |
# | 4.02.01 | Variação reflexa de reserva de ativos financeiros disponíveis para venda |
# | 4.02.01 | Efeito Cambial na Conversão das Demonstrações Financeiras e Realização de Variação Cambial de Contr |
# ...
# | 6.03.13 | Caixa e equivalentes a caixa de controladas excluídas na consolidação, líquido |
# | 6.03.13 | Pagamento de juros  de ações preferenciais |
# | 6.03.13 | Contraprestação de arrendamentos - direito de uso de Imóveis |
# | 6.03.13 | Liquidação - Títulos e valores mobiliários |
# | 6.03.13 | Amortização de Swap sobre Empréstimos |
# | 6.03.13 | Captação de empréstimos |
# | 6.03.13 | Pagamento de Imposto de Renda de Juros Sobre o Capital Próprio |
# | 6.03.13 | Recompra de ações para tesouraria |
# | 6.03.13 | Ações em tesouraria |
# | 6.03.13 | Pagamentos de ajustes em contratos de swap |
# | 6.03.13 | Amortização de empréstimos e financiamentos, arrendamentos, debêntures e floor plan |
# | 6.03.13 | Reservas de capital |
# | 6.03.13 | Aquisição de participação em controlada - parcelas diferidas pagas |
# | 6.03.13 | Resgate (aplicação) em títulos e valores mobiliários |
# | 6.03.13 | Redução de capital para não controladores |
# | 6.03.13 | Gasto com emissão de ações |
# | 6.03.13 | Custo de transação com debêntures |
# | 6.03.13 | Custos de transação relacionados a contribuições    de capital por acionistas não controladores |
# | 6.03.13 | Aumento de capital |
# | 6.03.13 | Pagamento cessão de direitos creditórios |
# | 6.03.13 | Investimento de não controladores |
# | 6.03.13 | Pagamentos de consócio - principal |
# | 6.03.13 | Amortização (Forfait) |
# | 6.03.13 | Pagamento de instrumentos financeiros, líquido |
# | 6.03.13 | Pagamento de Contas a Pagar Por Aquisição de Controladas |
# | 6.03.13 | Pagamento de dividendos |
# | 6.03.13 | Capitação de Empréstimos |
# | 6.03.13 | Juros sobre Debêntures |
# | 6.03.13 | Derivativos tomados |
# | 6.03.13 | Caixa Líquido das Atividades de Financiamento Descontinuadas |
# | 6.03.14 | Liquidação Opção de venda de ações rede energia participações |
# | 6.03.14 | Gastos Com Operação Descontinuada |
# | 6.03.14 | Recebimento de instrumentos financeiros derivativos |
# | 6.03.14 | Recompra de debêntures |
# | 6.03.14 | Arrendamento - pagamentos de principal e juros |
# | 6.03.14 | Pagamentos de Arrendamentos |
# | 6.03.14 | Recebimento empréstimos empresas ligadas - juros |
# | 6.03.14 | Aumento de capital social em subsidiárias por não controladores |
# | 6.03.14 | Dividendos minimos e adicionais pagos |
# | 6.03.14 | Antecipação de recebíveis futuros |
# | 6.03.14 | Pré-pagamento principal debêntures |
# | 6.03.14 | Custos de Enissão de Ações |
# | 6.03.14 | Pagamento de obrigações a pagar por aquisições de shopping |
# | 6.03.14 | Novas cessões de direitos creditórios |
# | 6.03.14 | Partes Relacionadas |
# | 6.03.14 | Pagamento de debêntures |
# | 6.03.14 | Mútuos a Pagar - Partes relacionadas |
# | 6.03.14 | Valores recebidos de passivo de cessão (venda de recebíveis) |
# | 6.03.14 | Amortização do certificado de recebíveis imobiliários |
# | 6.03.14 | Custos na captação de empréstimos e financiamentos |
# | 6.03.14 | Distribuição de dividendos |
# | 6.03.14 | Adiantamento para Futuro Aumento de Capital F |
# | 6.03.14 | Alienação de ações em tesouraria |
# | 6.03.14 | Custos incorridos com a emissão de empréstimos |
# | 6.03.14 | Dividendos distribuídos |
# | 6.03.14 | Recompra de ações |
# | 6.03.14 | Adiantamento para futuro aumento de capital |
# | 6.03.14 | Pagamentos de Arrendamento |
# | 6.03.14 | Pagamento de obrigações por conta de aquisição de investimentos |
# | 6.03.14 | Dividendos pagos a sócios não controladores |
# | 6.03.14 | Ações em tesouraria adquiridas |
# | 6.03.14 | Juros Capitalizados |
# | 6.03.14 | Custo de captação de empréstimos e financiamentos / debêntures |
# | 6.03.14 | Depósitos bancários vinculados |
# | 6.03.14 | Outros |
# | 6.03.14 | Amortização de principal de Certificados de Recebíveis do Agronegócio |
# | 6.03.14 | Pagamento de parcelamento de aquisição de empresa |
# | 6.03.14 | Caixa e equivalentes a caixa de controladas incluidas na consolidação, líquido |
# | 6.03.14 | Pagamento de juros de debêntures |
# | 6.03.14 | Dividendos pagos |
# | 6.03.14 | Recebimento - Instrumentos financeiros |
# | 6.03.14 | Aumento de Capital |
# | 6.03.14 | Pagamento de empréstimos |
# | 6.03.14 | Instrumentos financeiros derivativos |
# | 6.03.14 | Aumento de capital realizado por acionistas não-controladores e regate de cotas |
# | 6.03.14 | Recompra parcial de Senior Notes Due 2027 |
# | 6.03.14 | Recebimentos de ajustes em contratos de swap |
# | 6.03.14 | Pagamento de derivativos contratados |
# | 6.03.14 | Pagamento de passivo de arrendamento (principal) |
# | 6.03.14 | Custo de emissão - Empréstimos e debêntures |
# | 6.03.14 | Custos na captação de empréstimos |
# | 6.03.14 | Arrendamentos |
# | 6.03.14 | Opções de compra de ações |
# | 6.03.14 | Despesas com oferta publica de ações |
# | 6.03.14 | Captação de cessão de recebíveis com direito de regresso |
# | 6.03.14 | Recursos provenientes da venda de ações em tesouraria |
# | 6.03.14 | Ágio na subscrição de ações |
# | 6.03.14 | Efeitos de variações cambiais sobre caixa e equivalentes de caixa |
# | 6.03.14 | Aumento de capital |
# | 6.03.14 | Pagamentos de consócio - juros |
# | 6.03.14 | (-) Alienação de ações em tesouraria |
# | 6.03.14 | Amortização de principal - Contratos de  arrendamento |
# | 6.03.15 | Novos parcelamentos de imposto |
# | 6.03.15 | Outros |
# | 6.03.15 | Captação de empréstimos empresas ligadas |
# | 6.03.15 | Aquisição de participação de não controladores |
# | 6.03.15 | Liquidação de operações com derivativos |
# | 6.03.15 | Baixa de acionistas não controladores |
# | 6.03.15 | Pagamentos de antecipação de recebíveis futuros - principal |
# | 6.03.15 | Recursos provenientes da emissão de ações |
# | 6.03.15 | Alienação de ações |
# | 6.03.15 | Juros sobre capital próprio pagos |
# | 6.03.15 | Repasse de cessão de direitos creditórios |
# | 6.03.15 | Pagamento de juros sobre capital próprio |
# | 6.03.15 | Valores a receber - Partes Relacionadas |
# | 6.03.15 | Contribuição de capital por minoritários |
# | 6.03.15 | Adição de outros passivos financeiros |
# | 6.03.15 | Amortização do passivo de arrendamento |
# | 6.03.15 | Pagamento de passivos de arrendamento |
# | 6.03.15 | Pagamentos de arrendamentos |
# | 6.03.15 | Recebimento pelo exercício de opção de ações |
# | 6.03.15 | Pagamento de empréstimo e derivativo swap |
# | 6.03.15 | Pagamento intangível - Parceria Unimed |
# | 6.03.15 | Recursos Captados nas Emissões de Novas Ações |
# | 6.03.15 | Amortização de empréstimos |
# | 6.03.15 | Pagamento arrendamento mercantil |
# | 6.03.15 | Aumento de capital |
# | 6.03.15 | Recompra de bond |
# | 6.03.15 | Recompra de ações em tesouraria |
# | 6.03.15 | Amortização de passivo de arrendamento |
# | 6.03.15 | Ingresso de novos acionistas controladores |
# | 6.03.15 | Passivo de Arrendamento |
# | 6.03.15 | Venda de Ações em Tesouraria |
# | 6.03.15 | Pagamento de juros sobre empréstimos |
# | 6.03.15 | Caixa líquido consumido nas atividades de financiamentos das operações descontinuadas |
# | 6.03.15 | Captação de floor plan |
# | 6.03.15 | (Aplicações) Resgates de garantias de financiamento |
# | 6.03.15 | Pagamento de risco sacado |
# | 6.03.15 | Recebimento de derivativo (swap) |
# | 6.03.15 | Instrumento financeiros derivativos pagos |
# | 6.03.15 | Pagamento de derivativos |
# | 6.03.15 | Pagamento de principal de cessão de recebíveis com direito de regresso |
# | 6.03.15 | Custos de transação relacionados a empréstimos e financiamentos |
# | 6.03.15 | Realização do gasto com emissão de ações |
# | 6.03.15 | Acordo de financiamento de fornecedor - risco sacado |
# | 6.03.15 | Pagamento de arrendamento mercantil |
# | 6.03.15 | Amortização de juros - Contratos de arrendamento |
# | 6.03.16 | Parcelamento de impostos |
# | 6.03.16 | Caixa Margem |
# | 6.03.16 | Pagamento empréstimos empresas ligadas - principal |
# | 6.03.16 | Operações descontinuadas líquido de caixa |
# | 6.03.16 | Títulos recebidos |
# | 6.03.16 | Pagamentos de antecipação de recebíveis futuros - juros |
# | 6.03.16 | Recompra de ações próprias |
# | 6.03.16 | Recompra de ações |
# | 6.03.16 | Resgate dos valores depositados em garantia |
# | 6.03.16 | Pagamento de derivativos contratados |
# | 6.03.16 | Pagamento de arrendamentos |
# | 6.03.16 | Efeitos em transação de capital |
# | 6.03.16 | Aquisição de Participações de Não Controladores |
# | 6.03.16 | Venda de ações para não controladores |
# | 6.03.16 | Juros pagos de empréstimos, financiamentos e debêntures |
# | 6.03.16 | Aquisição de ações de própria emissão |
# | 6.03.16 | Transação de capital |
# | 6.03.16 | Recebimento de capital social a integralizar em controlada por minoritários |
# | 6.03.16 | Efeitos das mudanças de câmbio sobre  o saldo de caixa mantido em moedas  estrangeiras |
# | 6.03.16 | Gastos com a Emissão de Ações |
# | 6.03.16 | Aporte/(Redução de capital) de não controladores |
# | 6.03.16 | Fornecedores convênio |
# | 6.03.16 | Adiantamento para futuro aumento de capital |
# | 6.03.16 | Recompra de debêntures |
# | 6.03.16 | Aumento de capital social |
# | 6.03.16 | Contraprestação de arrendamentos - equipamentos de ginástica |
# | 6.03.16 | Pagamento dividendos |
# | 6.03.16 | Captações de passivo financeiro de clientes |
# | 6.03.16 | Amortização de floor plan |
# | 6.03.16 | Redução de capital |
# | 6.03.16 | Juros pagos sobre arrendamentos |
# | 6.03.16 | Mútuo |
# | 6.03.16 | Pagamento de principal de empréstimos, financiamentos e debêntures |
# | 6.03.16 | Amortização de principal sobre arrendamentos |
# | 6.03.16 | Pagamento de instrumentos derivativos de hedge |
# | 6.03.17 | Aquisição de participação de não controladores Diamond Valley Pork |
# | 6.03.17 | Pagamento empréstimos empresas ligadas - juros |
# | 6.03.17 | Alienação de participação em controlada sem perda de controle |
# | 6.03.17 | Custo de transação relacionados à captações |
# | 6.03.17 | Recompra de debenturê |
# | 6.03.17 | Pagamentos de custo de estruturação |
# | 6.03.17 | Transação compra ações termo síntetico |
# | 6.03.17 | Recompra de ações, líquida de recebimentos pela opção de ações exercidas |
# | 6.03.17 | Redução da reserva de capital |
# | 6.03.17 | Aumento de capital |
# | 6.03.17 | Custos a apropriar - Debêntures |
# | 6.03.17 | Caixa adquirido em incorporações |
# | 6.03.17 | Recompra de ações |
# | 6.03.17 | Pagamentos de juros fornecedores conveniados |
# | 6.03.17 | Dividendos |
# | 6.03.17 | Venda de recebiveis |
# | 6.03.17 | Instrumentos financeiros derivativos pagos |
# | 6.03.17 | Pagamentos de passivo financeiro de clientes |
# | 6.03.17 | Recebimento de ajuste de preço de compra de subsidiária |
# | 6.03.17 | Juros pagos sobre debêntures |
# | 6.03.17 | Pagamento de juros sobre arrendamentos |
# | 6.03.18 | Emissão de Debêntures |
# | 6.03.18 | Remuneração de credores - refinanciamento |
# | 6.03.18 | Aquisição de controladas - Pagamentos |
# | 6.03.18 | Pagamento de obrigações por aquisição de empresas |
# | 6.03.18 | Redução de capital em controladas |
# | 6.03.18 | Aporte de capital de outros acionistas não controladores - Spice |
# | 6.03.18 | Adição ao passivo de arrendamento |
# | 6.03.18 | Ingressos em parcelamento de impostos |
# | 6.03.18 | Compra de ações a termo |
# | 6.03.18 | Efeito de caixa e equivalentes de caixa de operações descontinuadas |
# | 6.03.18 | Juros pagos sobre empréstimos |
# | 6.03.18 | Custos de operações bancárias com derivativos |
# | 6.03.19 | Pagamento Debêntures - principal |
# | 6.03.19 | Dividendos pagos para acionistas não controladores |
# | 6.03.19 | Pagamento de plano de remuneração baseado em ações - Stock grant |
# | 6.03.19 | Dividendos pagos aos acionistas não controladores |
# | 6.03.19 | Outros valores pagos à participação não controladora |
# | 6.03.19 | Aquisição de bônus perpétuo pela GP Cash |
# | 6.03.19 | Custo de emissão de ações (follow on) |
# | 6.03.19 | Captação de empréstimo: mútuo com partes relacionadas |
# | 6.03.19 | Ganho nas operações bancárias de derivativos |
# | 6.03.20 | Pagamento Debêntures - juros |
# | 6.03.20 | Liquidação de instrumento financeiro |
# | 6.03.20 | Pagamento de juros e principal sobre passivo de arrendamento |
# | 6.03.20 | Aumento de capital, líquido dos custos da transação |
# | 6.03.20 | Pagamento de juros sobre empréstimos e financiamentos |
# | 6.03.20 | Pagamentos de dividendos |
# | 6.03.20 | Mútuos pagos - partes relacionadas |
# | 6.03.20 | Dividendos pagos acionistas preferencialistas |
# | 6.03.20 | Outros |
# | 6.04 | Efeitos de Variação Cambial s/ Caixa e Equivalentes |
# | 6.04 | Variação Cambial s/ Caixa e Equivalentes |
# | 6.05 | Aumento (Redução) de Caixa e Equivalentes |
# | 6.05.01 | Saldo Inicial de Caixa e Equivalentes |
# | 6.05.02 | Saldo Final de Caixa e Equivalentes |
# | 7.01 | Receitas |
# | 7.01.01 | Intermediação Financeira |
# | 7.01.01 | Vendas de Mercadorias, Produtos e Serviços |
# | 7.01.01 | Receitas com Operações de Seguros/Resseguros |
# | 7.01.02 | Prestação de Serviços |
# | 7.01.02 | Outras Receitas |
# | 7.01.02 | Receitas Operações Previd. Complementar (sem risco atuarial) |
# | 7.01.03 | Provisão/Reversão Perdas Esperadas de Risco de Crédito |
# | 7.01.03 | Receitas refs. à Construção de Ativos Próprios |
# | 7.01.03 | Provisão/Reversão de Créds. Liquidação Duvidosa |
# | 7.01.03 | Rendas com Taxas Gestão e Outras Taxas |
# | 7.01.04 | Outras |
# | 7.01.04 | Provisão/Reversão de Créds. Liquidação Duvidosa |
# | 7.01.05 | Provisão/Reversão de Créds. Liquidação Duvidosa |
# | 7.02 | Despesas de Intermediação Financeira |
# | 7.02 | Insumos Adquiridos de Terceiros |
# | 7.02 | Variações das Provisões Técnicas |
# | 7.02.01 | Custos Prods., Mercs. e Servs. Vendidos |
# | 7.02.01 | Operações de Seguros |
# | 7.02.01 | Despesas de Tarifas e Comissões, liquidas |
# | 7.02.01 | Juros e Similares |
# | 7.02.02 | Materiais, Energia, Servs. de Terceiros e Outros |
# | 7.02.02 | Operações de Previdência |
# | 7.02.02 | Despesas com Juros e Similares |
# | 7.02.03 | Perda/Recuperação de Valores Ativos |
# | 7.02.03 | Outras |
# | 7.02.04 | Outros |
# | 7.03 | Insumos Adquiridos de Terceiros |
# | 7.03 | Valor Adicionado Bruto |
# | 7.03 | Receita Operacional Líquida |
# | 7.03.01 | Materiais, Energia e Outros |
# | 7.03.02 | Serviços de Terceiros |
# | 7.03.03 | Perda/Recuperação de Valores Ativos |
# | 7.03.04 | Outros |
# | 7.04 | Valor Adicionado Bruto |
# | 7.04 | Retenções |
# | 7.04 | Outros benefícios |
# | 7.04.01 | Depreciação, Amortização e Exaustão |
# | 7.04.01 | Outros |
# | 7.04.02 | Outras |
# | 7.05 | Retenções |
# | 7.05 | Valor Adicionado Líquido Produzido |
# | 7.05 | Insumos Adquiridos de Terceiros |
# | 7.05.01 | Depreciação, Amortização e Exaustão |
# | 7.05.01 | Materiais, Energia e Outros |
# | 7.05.02 | Outras |
# | 7.05.02 | Serviços Terceiros - Comissões Líquidas |
# | 7.05.03 | Var. Despesas Comercialização Diferidas |
# | 7.05.04 | Perda/Recuperação de Valores Ativos |
# | 7.05.05 | Outros |
# | 7.06 | Valor Adicionado Líquido Produzido |
# | 7.06 | Vlr Adicionado Recebido em Transferência |
# | 7.06 | Valor Adicionado Bruto |
# | 7.06.01 | Resultado de Equivalência Patrimonial |
# | 7.06.02 | Receitas Financeiras |
# | 7.06.03 | Outros |
# | 7.07 | Vlr Adicionado Recebido em Transferência |
# | 7.07 | Valor Adicionado Total a Distribuir |
# | 7.07 | Retenções |
# | 7.07.01 | Resultado de Equivalência Patrimonial |
# | 7.07.01 | Depreciação, Amortização e Exaustão |
# | 7.07.02 | Outros |
# | 7.07.02 | Outras |
# | 7.08 | Valor Adicionado Total a Distribuir |
# | 7.08 | Distribuição do Valor Adicionado |
# | 7.08 | Valor Adicionado Líquido Produzido |
# | 7.08.01 | Pessoal |
# | 7.08.02 | Impostos, Taxas e Contribuições |
# | 7.08.03 | Remuneração de Capitais de Terceiros |
# | 7.08.04 | Remuneração de Capitais Próprios |
# | 7.08.05 | Outros |
# | 7.09 | Distribuição do Valor Adicionado |
# | 7.09 | Vl Adic Recebido/Cedido em Transferência |
# | 7.09.01 | Pessoal |
# | 7.09.01 | Receitas Financeiras |
# | 7.09.02 | Impostos, Taxas e Contribuições |
# | 7.09.02 | Resultado de Equivalência Patrimonial |
# | 7.09.03 | Remuneração de Capitais de Terceiros |
# | 7.09.03 | Resultado Operações Resseguros Cedidos |
# | 7.09.04 | Remuneração de Capitais Próprios |
# | 7.09.04 | Resultado Operações Cosseguros Cedidos |
# | 7.09.05 | Outros |
# | 7.10 | Valor Adicionado Total a Distribuir |
# | 7.11 | Distribuição do Valor Adicionado |
# | 7.11.01 | Pessoal |
# | 7.11.02 | Impostos, Taxas e Contribuições |
# | 7.11.03 | Remuneração de Capitais de Terceiros |
# | 7.11.04 | Remuneração de Capitais Próprios |
# | 7.11.05 | Outros |
