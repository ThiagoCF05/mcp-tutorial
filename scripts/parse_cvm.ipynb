# %%
import os
import pandas as pd

from datetime import datetime

DFP_PATH = "/Users/thiagocastroferreira/Desktop/kubernetes/datasets/DFP"
ITR_PATH = "/Users/thiagocastroferreira/Desktop/kubernetes/datasets/ITR"

gold_standard = pd.read_csv(
    "/Users/thiagocastroferreira/Desktop/kubernetes/mcp-tutorial/fundamental_analysis/2025-04-17/fundamental_analysis.csv"
)

stocks = [
    {
        "id": "AFLT3",
        "cnpj": "10.338.320/0001-00",
        "name": "Afluente Transmissão de Energia",
    },
    {"id": "ALUP11", "cnpj": "08.364.948/0001-38", "name": "Alupar Investimento"},
    {"id": "AURE3", "cnpj": "28.594.234/0001-23", "name": "Auren Energia"},
    {"id": "CBEE3", "cnpj": "33.050.071/0001-58", "name": "Ampla Energia e Serviços"},
    {"id": "CEEB3", "cnpj": "15.139.629/0001-94", "name": "COELBA"},
    {
        "id": "CPLE3",
        "cnpj": "76.483.817/0001-20",
        "name": "Companhia Paranaense de Energia",
    },
    {"id": "EGIE3", "cnpj": "02.474.103/0001-19", "name": "Engie Brasil Energia"},
    {
        "id": "COCE3",
        "cnpj": "07.047.251/0001-70",
        "name": "Companhia Energértica do Ceará",
    },
    {"id": "EKTR4", "cnpj": "02.328.280/0001-97", "name": "Elektro Redes"},
    {"id": "ELET3", "cnpj": "00.001.180/0001-26", "name": "Eletrobrás"},
    {"id": "ENEV3", "cnpj": "04.423.567/0001-21", "name": "Eneva"},
    {"id": "ENGI3", "cnpj": "00.864.214/0001-06", "name": "Energisa"},
    {"id": "ENMT3", "cnpj": "03.467.321/0001-99", "name": "Energisa Mato Grosso"},
    {"id": "EQTL3", "cnpj": "03.220.438/0001-73", "name": "Equatorial"},
    {"id": "ISAE3", "cnpj": "02.998.611/0001-04", "name": "ISA Energia Brasil"},
    {"id": "LIGT3", "cnpj": "03.378.521/0001-75", "name": "Light"},
    {"id": "NEOE3", "cnpj": "01.083.200/0001-18", "name": "Neoenergia"},
    {"id": "RNEW11", "cnpj": "08.534.605/0001-74", "name": "Renova Energia"},
    {"id": "SRNA3", "cnpj": "42.500.384/0001-51", "name": "Serena Energia"},
]
stock_cnpjs = [stock["cnpj"] for stock in stocks]

forms = [
    "BPA_con",
    "BPP_con",
    "DFC_MD_con",
    "DFC_MI_con",
    "DMPL_con",
    "DRA_con",
    "DRE_con",
    "composicao",
    "DVA_con",
    "parecer",
]

ORDEM_EXERC = "ÚLTIMO"
mapping = {
    "CNPJ": "CNPJ_CIA",
    "REPORT_DATE": "DT_REFER",
    "COMPANY_NAME": "DENOM_CIA",
    "CVM_CODE": "CD_CVM",
    "DFP_GROUP": "GRUPO_DFP",
    "VERSION": "VERSAO",
    "CURRENCY": "MOEDA",
    "EXERC_ORDER": "ORDEM_EXERC",
    "ANALYSIS_START_PERIOD_DATE": "DT_INI_EXERC",
    "ANALYSIS_END_PERIOD_DATE": "DT_FIM_EXERC",
    "ACCOUNT_NUMBER": "CD_CONTA",
    "ACCOUNT_NAME": "DS_CONTA",
    "ACCOUNT_VALUE": "VL_CONTA",
    "IS_FIXED_ACCOUNT": "ST_CONTA_FIXA",
}

DATABASE_PATH = "cvm.db"

with open(DATABASE_PATH, "w") as f:
    f.write("")

# %% [markdown]
# # Processamento
#
# - Balanço Patrimonial Ativo (BPA)
# - Balanço Patrimonial Passivo (BPP)
# - Demonstração de Fluxo de Caixa - Método Direto (DFC-MD)
# - Demonstração de Fluxo de Caixa - Método Indireto (DFC-MI)
# - Demonstração das Mutações do Patrimônio Líquido (DMPL)
# - Demonstração de Resultado Abrangente (DRA)
# - Demonstração de Resultado (DRE)
# - Demonstração de Valor Adicionado (DVA)

# %%
def process_forms(form_path: str) -> pd.DataFrame:
    result_forms = []
    for year in [fname for fname in os.listdir(form_path) if not fname.startswith(".")]:
        year_path = os.path.join(form_path, year)
        for form in [
            "BPA_con",
            "BPP_con",
            "DFC_MD_con",
            "DFC_MI_con",
            "DMPL_con",
            "DRA_con",
            "DRE_con",
            "DVA_con",
        ]:
            path = [path for path in os.listdir(year_path) if form in path][0]
            path = os.path.join(year_path, path)

            with open(path, "r", encoding="latin-1") as f:
                doc = f.readlines()

            header, rows = doc[0].strip().split(";"), doc[1:]

            results = []
            for row in rows:
                row = row.strip().split(";")
                key_value = {key: value for key, value in zip(header, row)}
                if (
                    key_value["CNPJ_CIA"] not in stock_cnpjs
                    # or key_value["ORDEM_EXERC"] != "ÚLTIMO"
                ):
                    continue

                unit = 1
                if key_value["ESCALA_MOEDA"] == "MIL":
                    unit = 1000

                if form in ["BPA_con", "BPP_con"]:
                    dict_row = {
                        key: key_value[mapping[key]]
                        for key in mapping
                        if key != "ANALYSIS_START_PERIOD_DATE"
                    }
                else:
                    dict_row = {key: key_value[mapping[key]] for key in mapping}
                    dict_row["ANALYSIS_START_PERIOD_DATE"] = datetime.strptime(
                        dict_row["ANALYSIS_START_PERIOD_DATE"], "%Y-%m-%d"
                    )

                dict_row["IS_FIXED_ACCOUNT"] = (
                    True if dict_row["IS_FIXED_ACCOUNT"] == "S" else False
                )
                if "COLUNA_DF" in key_value:
                    dict_row["ACCOUNT_NAME"] = (
                        key_value["COLUNA_DF"].strip()
                        + " - "
                        + dict_row["ACCOUNT_NAME"]
                    )
                dict_row["ACCOUNT_VALUE"] = float(dict_row["ACCOUNT_VALUE"]) * unit
                dict_row["ANALYSIS_END_PERIOD_DATE"] = datetime.strptime(
                    dict_row["ANALYSIS_END_PERIOD_DATE"], "%Y-%m-%d"
                )
                dict_row["REPORT_DATE"] = datetime.strptime(
                    dict_row["REPORT_DATE"], "%Y-%m-%d"
                )

                results.append(dict_row)

            df = pd.DataFrame(results)
            result_forms.append(df)

    df = pd.concat(result_forms)
    return df

# %%
df_dfp = process_forms(DFP_PATH)
df_itr = process_forms(ITR_PATH)

df = pd.concat([df_dfp, df_itr])

# %% [markdown]
# Criando base de dados

# %%
import sqlite3

command = """CREATE TABLE IF NOT EXISTS DFP_ITR_CVM (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
	CNPJ TEXT NOT NULL,
	REPORT_DATE DATETIME NOT NULL,
	COMPANY_NAME TEXT NOT NULL,
	CVM_CODE TEXT NOT NULL,
	DFP_GROUP TEXT NOT NULL,
	VERSION TEXT NOT NULL,
	CURRENCY TEXT NOT NULL,
 	EXERC_ORDER TEXT NOT NULL,
	ANALYSIS_START_PERIOD_DATE DATETIME,
	ANALYSIS_END_PERIOD_DATE DATETIME NOT NULL,
	ACCOUNT_NUMBER TEXT NOT NULL,
	ACCOUNT_NAME TEXT NOT NULL,
	ACCOUNT_VALUE FLOAT NOT NULL,
	IS_FIXED_ACCOUNT TEXT
);

-- Índice para consultas por CNPJ
CREATE INDEX IF NOT EXISTS idx_dfp_itr_cvm_cnpj 
ON DFP_ITR_CVM (CNPJ);

-- Índice para consultas por data de início de período
CREATE INDEX IF NOT EXISTS idx_dfp_itr_cvm_start_date 
ON DFP_ITR_CVM (ANALYSIS_START_PERIOD_DATE);"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(DATABASE_PATH)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
cursor.executescript(command)

# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# Populando base de dados

# %%
queries = []

fields = list(mapping.keys())
fields_str = ", ".join(fields)
placeholders = ", ".join(["?"] * len(fields))

query = f"INSERT INTO DFP_ITR_CVM ({fields_str}) VALUES ({placeholders})"

data = []  # list of tuples to insert

for idx, row in df.iterrows():
    if len(row["ACCOUNT_NUMBER"].split(".")) > 3:
        continue

    row_values = []
    for field in fields:
        value = row[field]
        if isinstance(value, datetime):
            try:
                value = value.strftime("%Y-%m-%d")
            except Exception:
                value = "NULL"
        elif isinstance(value, float) and (value != value):  # NaN check
            value = None
        elif value == "NULL" or value == "":
            value = None
        row_values.append(value)

    data.append(tuple(row_values))

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(DATABASE_PATH)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
# Bulk insert safely
cursor.executemany(query, data)
# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# # Processamento Composição
#
# Carregando e limpando os dados

# %%
mapping = {
    "CNPJ": "CNPJ_CIA",
    "REPORT_DATE": "DT_REFER",
    "COMPANY_NAME": "DENOM_CIA",
    "VERSION": "VERSAO",
    "ORDINARY_SHARES_ISSUED": "QT_ACAO_ORDIN_CAP_INTEGR",
    "ORDINARY_SHARES_TREASURY": "QT_ACAO_ORDIN_TESOURO",
    "PREFERRED_SHARES_ISSUED": "QT_ACAO_PREF_CAP_INTEGR",
    "PREFERRED_SHARES_TREASURY": "QT_ACAO_PREF_TESOURO",
    "TOTAL_SHARES_ISSUED": "QT_ACAO_TOTAL_CAP_INTEGR",
    "TOTAL_SHARES_TREASURY": "QT_ACAO_TOTAL_TESOURO",
}

form = "composicao"
results = []
for PATH in [DFP_PATH, ITR_PATH]:
    for year in [fname for fname in os.listdir(PATH) if not fname.startswith(".")]:
        year_path = os.path.join(PATH, year)
        path = [path for path in os.listdir(year_path) if form in path][0]
        path = os.path.join(year_path, path)

        with open(path, "r", encoding="latin-1") as f:
            doc = f.readlines()

        header, rows = doc[0].strip().split(";"), doc[1:]

        for row in rows:
            row = row.strip().split(";")
            key_value = {key: value for key, value in zip(header, row)}
            if key_value["CNPJ_CIA"] not in stock_cnpjs:
                continue

            dict_row = {key: key_value[mapping[key]] for key in mapping}
            stock_id = [s["id"] for s in stocks if s["cnpj"] == key_value["CNPJ_CIA"]][
                0
            ]
            stock_number = int(
                gold_standard[(gold_standard["Papel"] == stock_id)]["Nro. Ações"]
            )
            unit = 1
            if (stock_number / int(dict_row["TOTAL_SHARES_ISSUED"])) > 500:
                unit = 1000

            dict_row["REPORT_DATE"] = datetime.strptime(
                dict_row["REPORT_DATE"], "%Y-%m-%d"
            )
            dict_row["ORDINARY_SHARES_ISSUED"] = (
                int(dict_row["ORDINARY_SHARES_ISSUED"]) * unit
            )
            dict_row["ORDINARY_SHARES_TREASURY"] = (
                int(dict_row["ORDINARY_SHARES_TREASURY"]) * unit
            )
            dict_row["PREFERRED_SHARES_ISSUED"] = (
                int(dict_row["PREFERRED_SHARES_ISSUED"]) * unit
            )
            dict_row["PREFERRED_SHARES_TREASURY"] = (
                int(dict_row["PREFERRED_SHARES_TREASURY"]) * unit
            )
            dict_row["TOTAL_SHARES_ISSUED"] = (
                int(dict_row["TOTAL_SHARES_ISSUED"]) * unit
            )
            dict_row["TOTAL_SHARES_TREASURY"] = (
                int(dict_row["TOTAL_SHARES_TREASURY"]) * unit
            )

            results.append(dict_row)

df = pd.DataFrame(results)
# Out:
# /var/folders/1p/jbswfpbs73q5qbbh78dzj5xm0000gn/T/ipykernel_90470/2240919176.py:37: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   stock_number = int(

# %% [markdown]
# Criando base de dados

# %%
command = """CREATE TABLE IF NOT EXISTS CVM_SHARE_COMPOSITION (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
	CNPJ TEXT NOT NULL,
    REPORT_DATE DATETIME NOT NULL,
    COMPANY_NAME TEXT NOT NULL,
    VERSION TEXT NOT NULL,
    ORDINARY_SHARES_ISSUED INTEGER NOT NULL,
    ORDINARY_SHARES_TREASURY INTEGER NOT NULL,
    PREFERRED_SHARES_ISSUED INTEGER NOT NULL,
    PREFERRED_SHARES_TREASURY INTEGER NOT NULL,
    TOTAL_SHARES_ISSUED INTEGER NOT NULL,
    TOTAL_SHARES_TREASURY INTEGER NOT NULL
)"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(DATABASE_PATH)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
cursor.executescript(command)

# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %% [markdown]
# Inserindo os dados

# %%
queries = []

fields = list(mapping.keys())
fields_str = ", ".join(fields)
placeholders = ", ".join(["?"] * len(fields))

query = f"INSERT INTO CVM_SHARE_COMPOSITION ({fields_str}) VALUES ({placeholders})"

data = []  # list of tuples to insert

for idx, row in df.iterrows():
    row_values = []
    for field in fields:
        value = row[field]
        if isinstance(value, datetime):
            value = value.strftime("%Y-%m-%d")
        row_values.append(value)

    data.append(tuple(row_values))

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(DATABASE_PATH)

# Create a cursor object using the connection
cursor = connection.cursor()

# Execute the command
# Bulk insert safely
cursor.executemany(query, data)
# Commit the changes to the database
connection.commit()

# Close the cursor and connection
cursor.close()
connection.close()

# %%
command = """SELECT DISTINCT ACCOUNT_NUMBER, ACCOUNT_NAME FROM DFP_ITR_CVM ORDER BY ACCOUNT_NUMBER"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(DATABASE_PATH)

# Create a cursor object using the connection
cursor = connection.cursor()

# Query the database
cursor.execute(command)

# Fetch column names
columns = (
    [description[0] for description in cursor.description] if cursor.description else []
)

# Fetch results
rows = cursor.fetchall()

# Close the cursor and connection
cursor.close()
connection.close()

# Format results as markdown table
if not rows:
    output = "No data found with given query"
else:
    # Create markdown table
    output = "| " + " | ".join(columns) + " |\n"
    output += "| " + " | ".join(["---" for _ in columns]) + " |\n"
    for row in rows:
        output += (
            "| "
            + " | ".join([str(cell) if cell is not None else "" for cell in row])
            + " |\n"
        )

print(output)
# Out:
# | ACCOUNT_NUMBER | ACCOUNT_NAME |
# | --- | --- |
# | 1 | Ativo Total |
# | 1.01 | Ativo Circulante |
# | 1.01.01 | Caixa e Equivalentes de Caixa |
# | 1.01.02 | Aplicações Financeiras |
# | 1.01.03 | Contas a Receber |
# | 1.01.04 | Estoques |
# | 1.01.05 | Ativos Biológicos |
# | 1.01.06 | Tributos a Recuperar |
# | 1.01.07 | Despesas Antecipadas |
# | 1.01.08 | Outros Ativos Circulantes |
# | 1.02 | Ativo Não Circulante |
# | 1.02.01 | Ativo Realizável a Longo Prazo |
# | 1.02.02 | Investimentos |
# | 1.02.03 | Imobilizado |
# | 1.02.04 | Intangível |
# | 2 | Passivo Total |
# | 2.01 | Passivo Circulante |
# | 2.01.01 | Obrigações Sociais e Trabalhistas |
# | 2.01.02 | Fornecedores |
# | 2.01.03 | Obrigações Fiscais |
# | 2.01.04 | Empréstimos e Financiamentos |
# | 2.01.05 | Outras Obrigações |
# | 2.01.06 | Provisões |
# | 2.01.07 | Passivos sobre Ativos Não-Correntes a Venda e Descontinuados |
# | 2.02 | Passivo Não Circulante |
# | 2.02.01 | Empréstimos e Financiamentos |
# | 2.02.02 | Outras Obrigações |
# | 2.02.03 | Tributos Diferidos |
# | 2.02.04 | Provisões |
# | 2.02.05 | Passivos sobre Ativos Não-Correntes a Venda e Descontinuados |
# | 2.02.06 | Lucros e Receitas a Apropriar |
# | 2.03 | Patrimônio Líquido Consolidado |
# | 2.03.01 | Capital Social Realizado |
# | 2.03.02 | Reservas de Capital |
# | 2.03.03 | Reservas de Reavaliação |
# | 2.03.04 | Reservas de Lucros |
# | 2.03.05 | Lucros/Prejuízos Acumulados |
# | 2.03.06 | Ajustes de Avaliação Patrimonial |
# | 2.03.07 | Ajustes Acumulados de Conversão |
# | 2.03.08 | Outros Resultados Abrangentes |
# | 2.03.09 | Participação dos Acionistas Não Controladores |
# | 3.01 | Receita de Venda de Bens e/ou Serviços |
# | 3.01.01 | Receita bruta |
# | 3.01.01 | Receita de infra, operação e manutenção, ganho de eficiência da implem da infra e outras, líquidas |
# | 3.01.01 | Receita de implementação de infraestrutura, O&M e outras, líquidas |
# | 3.01.01 | Suprimento de energia elétrica |
# | 3.01.01 | Receita operacional líquida |
# | 3.01.01 | Receita de operação e manutenção, Infraestrutura, Suprimento de Energia e Prestação de serviços |
# | 3.01.01 | Receita de operação e manutenção |
# | 3.01.01 | Receita de infra, operação e manutenção, ganho de eficiência na implem da infra e outras, líquidas |
# | 3.01.01 | Receita de infra, operação e manutenção, ganho de eficiência na implem da infra e outras líquidas |
# | 3.01.01 | Receita de infra, operação e manutenção, ganho de eficiência da implem da infra e outras líquidas |
# | 3.01.01 | Receita de Operação e manutenção, Infraestrutura e Suprimento de energia |
# | 3.01.01 | Receita Operacional Líquida |
# | 3.01.01 | Receita Operacional Liquida |
# | 3.01.02 | (-) Deduções da receita bruta |
# | 3.01.02 | Remuneração dos ativos da concessão, líquidas |
# | 3.01.02 | Remuneração dos ativos da concessão, líquida |
# | 3.01.02 | Carteira de Trading - MTM |
# | 3.01.02 | Remuneração finaceira do ativo de concessão |
# | 3.01.02 | Receita de infraestrutura |
# | 3.01.02 | Remuneração dos ativos da concesão, líquida |
# | 3.01.02 | MTM Carteira de Trading |
# | 3.01.03 | Remuneração financeira do ativo de concessão |
# | 3.01.04 | Suprimento de energia |
# | 3.01.05 | Deduções da receita operacional bruta |
# | 3.02 | Custo dos Bens e/ou Serviços Vendidos |
# | 3.02.01 | Energia comprada para revenda |
# | 3.02.01 | Custo dos Serviços de Implementação da Infraestrutura e Operação e Manutenção |
# | 3.02.01 | Energia elétrica comprada para revenda |
# | 3.02.01 | Energia Comprada para Revenda |
# | 3.02.01 | Impostos e contribuições sobre a receita |
# | 3.02.01 | Custo com energia elétrica |
# | 3.02.01 | Compras de energia |
# | 3.02.01 | Energia elétrica comprada p/revenda |
# | 3.02.01 | Depreciação e Amortização |
# | 3.02.01 | Depreciação e amortização |
# | 3.02.01 | Custos com energia elétrica |
# | 3.02.02 | Encargos sobre uso da rede elétrica |
# | 3.02.02 | Custo de construção |
# | 3.02.02 | Encargos do Uso da Rede Elétrica - CUST |
# | 3.02.02 | Depreciação e Amortização |
# | 3.02.02 | Custo com operação |
# | 3.02.02 | Custo dos serviços prestados |
# | 3.02.02 | Transações no mercado de energia de curto prazo |
# | 3.02.02 | Encargos uso sistema transm.e distribuição |
# | 3.02.02 | Encargos de uso de rede elétrica e de conexão |
# | 3.02.02 | Custo de Construção |
# | 3.02.02 | Encargos do Uso da Rede Eletrica Cust |
# | 3.02.02 | Custo de Operação |
# | 3.02.02 | Custo de operação |
# | 3.02.02 | Compra e transporte do gás |
# | 3.02.02 | Custos de construção |
# | 3.02.02 | Encargos de uso do sistema de transmissão e distribuição |
# | 3.02.02 | Encargos sobre o uso da rede elétrica |
# | 3.02.02 | Encargos para uso da rede elétrica |
# | 3.02.03 | Combustível para produção de energia elétrica |
# | 3.02.03 | Custo da operação |
# | 3.02.03 | Compensação Financeira pela Utilização de Recursos Hídricos - CFURH |
# | 3.02.03 | Custo de Operação |
# | 3.02.03 | Repactuação do risco hidrológico |
# | 3.02.03 | Encargos de uso de rede elétrica e de conexão |
# | 3.02.03 | Pessoal e administradores |
# | 3.02.03 | Transações no mercado de energia de curto prazo |
# | 3.02.03 | Compensação Financeira pela Uilização de Recursos Hidricos |
# | 3.02.03 | Encargos do Uso do Sistema de Distribuição |
# | 3.02.03 | Encargos de uso do do sistema de distribuição |
# | 3.02.03 | Encargos de uso do sistema de transmissão e distribuição |
# | 3.04.01 | Despesas com Vendas |
# | 3.04.02 | Despesas Gerais e Administrativas |
# | 3.04.03 | Perdas pela Não Recuperabilidade de Ativos |
# | 3.04.04 | Outras Receitas Operacionais |
# | 3.04.05 | Outras Despesas Operacionais |
# | 3.04.06 | Resultado de Equivalência Patrimonial |
# | 3.05 | Resultado Antes do Resultado Financeiro e dos Tributos |
# | 3.06 | Resultado Financeiro |
# | 3.06.01 | Receitas Financeiras |
# | 3.06.02 | Despesas Financeiras |
# | 3.07 | Resultado Antes dos Tributos sobre o Lucro |
# | 3.08 | Imposto de Renda e Contribuição Social sobre o Lucro |
# | 3.08.01 | Corrente |
# | 3.08.02 | Diferido |
# | 3.09 | Resultado Líquido das Operações Continuadas |
# | 3.10 | Resultado Líquido de Operações Descontinuadas |
# | 3.10.01 | Lucro/Prejuízo Líquido das Operações Descontinuadas |
# | 3.10.02 | Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas |
# | 3.11 | Lucro/Prejuízo Consolidado do Período |
# | 3.11.01 | Atribuído a Sócios da Empresa Controladora |
# | 3.11.02 | Atribuído a Sócios Não Controladores |
# | 3.99 | Lucro por Ação - (Reais / Ação) |
# | 3.99.01 | Lucro Básico por Ação |
# | 3.99.02 | Lucro Diluído por Ação |
# | 4.01 | Lucro Líquido Consolidado do Período |
# | 4.02 | Outros Resultados Abrangentes |
# | 4.02.01 | Instrumentos financeiros ao valor Justo por meio de ORA |
# | 4.02.01 | Itens que não serão reclassificados para a demonstração do resultado |
# | 4.02.01 | Efeito dos planos de benefício e planos de saúde a empregados das investidas |
# | 4.02.01 | Remensuração de obrigações com  aposentadoria |
# | 4.02.01 | Benefício pós emprego - superávit (déficit) atuarial |
# | 4.02.01 | Resultado de hedge accounting de fluxo de caixa |
# | 4.02.01 | Ganho (perda) sobre passivos atuariais, líquido dos efeitos fiscais |
# | 4.02.01 | Ajustes Acumulados de Conversão |
# | 4.02.01 | Ajustes acumulados de conversão |
# | 4.02.01 | Instrumentos financeiros derivativos, líquido dos efeitos tributários |
# | 4.02.01 | Ganhos com Passivos Atuariais - não serão reclassificados para o resultado |
# | 4.02.01 | Mudança no valor justo dos instrumentos financeiros por meio de ORA |
# | 4.02.01 | Remensuração de obrigações com aposentadoria |
# | 4.02.01 | Resultados abrangentes (hedge e benefícios pós-emprego, líquidos de tributos diferidos) |
# | 4.02.01 | Perda sobre passivos atuariais, líquido dos efeitos fiscais |
# | 4.02.01 | Ajustes de Passivos Atuariais - não serão reclassificados para o resultado |
# | 4.02.01 | Ajustes de passivos atuariais - não serão reclassificados para o resultado |
# | 4.02.01 | Benefício pós emprego - Superávit atuarial |
# | 4.02.01 | Ganhos (perdas) com Passivos Atuariais - não serão reclassificados para o resultado |
# | 4.02.01 | Ganho (perda) líquido de hedge accounting de fluxo de caixa |
# | 4.02.01 | Perdas com Passivos Atuariais - não serão reclassificados para o resultado |
# | 4.02.01 | Instrumentos financeiros ao valor justo por meio de ORA |
# | 4.02.01 | Resultado Líquido de Operações Descontinuadas |
# | 4.02.01 | Hedge de fluxo |
# | 4.02.01 | Obrigações com benefícios à empregados |
# | 4.02.01 | Ganhos (perdas) não realizados em operações de HFC originados no exercício |
# | 4.02.01 | (Perdas) ganhos não realizados em operações de HFC originados no período |
# | 4.02.01 | (Perdas) ganhos não realizados em operações de HFC originados no período  |
# | 4.02.01 | Resultado de hedge acounting de fluxo de caixa |
# | 4.02.01 | Perdas sobre passivos atuariais, líquido dos efeitos fiscais |
# | 4.02.01 | Ativos disponíveis para venda |
# | 4.02.01 | Hedge de fluxo de caixa |
# | 4.02.01 | (Perdas) ganhos não realizados em operações de HFC originadas no período |
# | 4.02.01 | Resultados abrangentes (hedge e benefício pós-emprego, líquido de tributos diferidos) |
# | 4.02.01 | Ganho de passivo atuarial, líquido dos efeitos fiscais |
# | 4.02.01 | Ganho de passivo atuarial, líquido de tributos |
# | 4.02.01 | Ajustes de conversão de moeda estrangeira do período |
# | 4.02.01 | Efeito de conversão de moeda estrangeira |
# | 4.02.01 | Remensuração das obrigações com aposentadoria |
# | 4.02.01 | Resultado de hedge accounting de fluxo de caixa líquido |
# | 4.02.01 | Ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.01 | Perda (ganho) líquida de hedge accounting de fluxo de caixa |
# | 4.02.01 | Ganhos não realizados em operações de hedge de fluxo de caixa originados no exercício |
# | 4.02.01 | (Perdas) ganhos não realizados em operações de hedge de fluxo de caixa originados no exercício |
# | 4.02.01 | Efeitos dos planos de benefícios pós emprego |
# | 4.02.02 | IR/CSLL diferidos |
# | 4.02.02 | Itens que poderão ser reclassificados para a demonstração do resultado |
# | 4.02.02 | Resultado abrangente sobre hedge de fluxo de caixa das investidas |
# | 4.02.02 | Imposto de renda e contribuição social diferidos - obrigações com aposentadoria |
# | 4.02.02 | Impostos diferidos sobre  Benefício pós emprego - superávit (déficit) atuarial |
# | 4.02.02 | Benefícios pós emprego - resultados atuariais |
# | 4.02.02 | Ajustes de Avaliação Patrimonial |
# | 4.02.02 | Hedge de fluxo de caixa |
# | 4.02.02 | Realização de ajustes acumulados na conversão |
# | 4.02.02 | Remensuração de benefícios de aposentadoria, líquido dos efeitos tributários |
# | 4.02.02 | Ganhos com Passivos Atuariais - não serão reclassificados para o resultado - Equiv. patrim. |
# | 4.02.02 | IR / CSLL diferidos |
# | 4.02.02 | Ganhos/(perdas) com derivativos - a ser reclassificado posteriormente para o resultado |
# | 4.02.02 | Ajustes de Passivos Atuariais - não serão reclassificados para o resultado - Equiv. patrim. |
# | 4.02.02 | Ajustes de passivos atuariais - não serão reclassificados para o resultado - Equiv. patrim. |
# | 4.02.02 | IR/CSSL diferidos |
# | 4.02.02 | Imposto de renda e contribuição social diferidos |
# | 4.02.02 | Efeitos dos planos de benefícios pós emprego |
# | 4.02.02 | Outros Resultados Abrangentes |
# | 4.02.02 | Outros resultados abrangentes |
# | 4.02.02 | IR e CS diferidos - Ganhos (perdas) não realizados em operações de HFC originados no exercício |
# | 4.02.02 | IR e CS diferidos - (Perdas) ganhos não realizados em operações de HFC originados no período |
# | 4.02.02 | IR e CS diferidos - (Perdas) ganhos não realizados em operações de HFC originados no período  |
# | 4.02.02 | Equivalência patrimonial sobre outros resultados abrangentes em controlada em conjunto |
# | 4.02.02 | Ajustes de avaliação patrimonial |
# | 4.02.02 | Impairment de ativos disponíveis para venda |
# | 4.02.02 | Ativos disponíveis para venda |
# | 4.02.02 | Perda em ganho de participação reflexa |
# | 4.02.02 | Equivalência patrimonial - (Perdas) ganhos de HFC de controladas, líquidos dos impostos diferidos |
# | 4.02.02 | Tributos diferidos sobre ganho (perda) instrumentos financeiros derivativos |
# | 4.02.02 | Ganhos/(perdas) com derivativos |
# | 4.02.02 | - |
# | 4.02.02 | IR/ CSLL diferidos |
# | 4.02.02 | IR/ CSSL diferidos |
# | 4.02.03 | Ajustes ganhos e perdas atuariais |
# | 4.02.03 | Tributos s/resultados abrangentes |
# | 4.02.03 | Equivalência Patrimonial de obrigações com  aposentadoria |
# | 4.02.03 | Ajuste instrumento financeiro de controladas, por equivalência patrimonial, líquido |
# | 4.02.03 | Perdas com derivativos |
# | 4.02.03 | Imposto de renda e contribuição social diferidos |
# | 4.02.03 | Ativos disponiveis para venda |
# | 4.02.03 | Perda em participação de investida |
# | 4.02.03 | Tributos sobre Outros Resultados Abrangentes - não serão reclassificados para o resultado |
# | 4.02.03 | Participação no resultado abrangente das coligadas e controladas em conjunto |
# | 4.02.03 | Tributos sobre resultados abrangentes |
# | 4.02.03 | Equivalência patrimonial de obrigações com aposentadoria |
# | 4.02.03 | Ganhos/ (Perdas) com derivativos - não será reclassificado para resultado |
# | 4.02.03 | Ganho (perda) em participação de investida |
# | 4.02.03 | Alienação de instrumentos financeiros ao valor justo por meio de ORA |
# | 4.02.03 | Ganhos/ (Perdas) com derivativos |
# | 4.02.03 | Ajuste Instrumento Financeiro de controladas, por equivalência patrimonial |
# | 4.02.03 | Ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.03 | Ajustes acumulados de conversão |
# | 4.02.03 | Tributos diferidos sobre resultados abrangentes |
# | 4.02.03 | Equival. patrimonial das (perdas) ganhos de controladas em conjunto, líquidos dos impostos diferidos |
# | 4.02.03 | Ajuste Instrumento Financeiro de controladas, por equivalência patrimonial,  líquido |
# | 4.02.03 | Parcela efetiva das mudanças no valor justo dos hedges de fluxo de caixa - hedge accounting |
# | 4.02.03 | Reflexo da perda de valor justo de instrumentos de hedge em controlada em conjunto |
# | 4.02.03 | Impairment de ativos disponíveis para venda |
# | 4.02.03 | Remensuração de benefícios de aposentadoria, líquido dos efeitos tributários |
# | 4.02.03 | Participação no resultado abrangente das controladas, coligadas e controladas em conjunto |
# | 4.02.03 | Equivalência patrimonial - Ganhos (perdas) de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.03 | Ganho de passivo atuarial, líquido de tributos |
# | 4.02.03 | Mudança de participação em controlada |
# | 4.02.03 | Ganhos (perdas) não realizadas em operações de HFC originadas no período |
# | 4.02.03 | Ganhos (perdas) não realizados em operações de HFC originados no período |
# | 4.02.03 | (Perdas) ganhos não realizadas em operações de HFC originadas no período |
# | 4.02.03 | Ganho em participação de investida |
# | 4.02.03 | (Perdas) Ganhos realizadas em operações de HFC originadas no exercício |
# | 4.02.03 | Ajuste Instrumento Financeiro |
# | 4.02.03 | Ajuste ganhos e perdas atuariais |
# | 4.02.03 | Ajuste de ganho e perdas atuariais |
# | 4.02.03 | Equivalência patrimonial das perdas de controladas em conjunto, líquidos dos impostos diferidos |
# | 4.02.04 | IR/CSLL diferidos |
# | 4.02.04 | Transferência de impactos realizados para o lucro líquido |
# | 4.02.04 | (Perdas) ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.04 | Ajuste Instrumento Financeiro de Controladora, líquido |
# | 4.02.04 | Ganhos com derivativos |
# | 4.02.04 | Efeito da alienação/impairrment de ativos disponíveis para venda |
# | 4.02.04 | Outros resultados abrangentes |
# | 4.02.04 | Ganhos com Ativos Financeiros - poderão ser reclassificados p/ resultado |
# | 4.02.04 | Remensuração de obrigações de benefícios pós-emprego |
# | 4.02.04 | Ganhos (perdas) não realizadas em operações de HFC originados no exercício |
# | 4.02.04 | Ajustes de Ativos Financeiros - poderão ser reclassificados p/ resultado |
# | 4.02.04 | Participação no resultado abrangente das controladas e coligadas |
# | 4.02.04 | Perdas não realizadas em operações de HFC originados no exercício |
# | 4.02.04 | IR/CSSL diferidos |
# | 4.02.04 | Ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.04 | Imposto de renda e contribuição social diferidos |
# | 4.02.04 | IR e CS diferidos - Ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.04 | Imposto de renda e contribuição social diferidos - hedge accounting |
# | 4.02.04 | Ajuste de ganhos e perdas atuariais |
# | 4.02.04 | Obrigações com beneficios à empregados |
# | 4.02.04 | Transferência de impactos realizados para o lucro líquidox |
# | 4.02.04 | Equivalência patrimonial - Ganhos (perdas) de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.04 | Equivalência patrimonial - (Perdas) ganhos de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.04 | Efeito na alienação dos ativos disponíveis para venda |
# | 4.02.04 | Perda em participação de investida |
# | 4.02.04 | Obrigações com benefícios à empregados |
# | 4.02.04 | (Perdas) ganhos não realizados em operações de HFC originados no período |
# | 4.02.04 | IR e CS diferidos - (Perdas) ganhos não realizadas em operações de HFC originadas no período |
# | 4.02.04 | Provisão de IR e CS diferidos - (perdas) ganhos não realizados |
# | 4.02.04 | Ganhos (perdas) não realizados em operações de HFC originados no exercício |
# | 4.02.04 | IR e CS diferidos - Ganhos (perdas) não realizados em operações de HFC originados no período |
# | 4.02.04 | Perdas com Ativos Financeiros - poderão ser reclassificados p/ resultado |
# | 4.02.04 | Ganho de participação de investida |
# | 4.02.04 | Equivalência patrimonial das perdas de HFC de controlada em conj., líquidas dos impostos diferido |
# | 4.02.04 | Participação no resultado abrangente das subsidiárias, coligadas e sociedades de controle compart. |
# | 4.02.04 | IR/ CSSL diferidos |
# | 4.02.04 | Perdas realizadas em operações de hedge de fluxo de caixa |
# | 4.02.04 | Ganhos (Perdas) realizados em operações de hedge de fluxo de caixa originados no exercício |
# | 4.02.05 | Ajustes acumulados de conversão |
# | 4.02.05 | IR e CS diferidos - (Perdas) ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.05 | Alienação de participação societária |
# | 4.02.05 | Reflexo da perda de valor justo de instrumentos de hedge em controlada em conjunto |
# | 4.02.05 | Perda em participação de investida |
# | 4.02.05 | Tributos sobre Outros Resultados Abrangentes - poderão ser reclassificados para o resultado |
# | 4.02.05 | IR/CSLL diferidos |
# | 4.02.05 | IR e CS diferidos - Perdas não realizadas em operações de HFC originados no exercício |
# | 4.02.05 | Remensuração de benefícios de aposentadoria, líquido dos efeitos tributários |
# | 4.02.05 | Remensuração de obrigações de benefícios pós-emprego |
# | 4.02.05 | IR e CS diferidos - Ganhos não realizados em operações de HFC originados no exercício |
# | 4.02.05 | Perdas realizadas em operações de HFC originadas no exercício |
# | 4.02.05 | Mudança de participação em controlada em conjunto |
# | 4.02.05 | Ganho (perda) com derivativos |
# | 4.02.05 | Ganho com derivativos |
# | 4.02.05 | Ganho (Perda) com derivativos |
# | 4.02.05 | Variações de participação em controladas |
# | 4.02.05 | (Perdas) ganhos não realizadas em operações de HFC originadas no período |
# | 4.02.05 | Ganhos/perdas com derivativos, líquidos de impostos |
# | 4.02.05 | Equivalência patrimonial - (Perdas) ganhos de HFC de controladas, líquidos dos impostos diferidos |
# | 4.02.05 | Ganhos/perdas com derivativos |
# | 4.02.05 | Equivalência patrimonial - (Perdas) ganhos de HFC de controladas, líquidas dos impostos diferidos |
# | 4.02.05 | Outros resultados abrangentes |
# | 4.02.05 | Remuneração baseada em ações |
# | 4.02.05 | Transferências de impactos realizados para o lucro líquido |
# | 4.02.05 | Valor justo de instrumentos financeiros disponíveis para venda |
# | 4.02.05 | Reflexo da perda de valor justo de instrumentos de hedge |
# | 4.02.06 | IR/CSSL diferidos |
# | 4.02.06 | Equivalência patrimonial - (Perdas) ganhos de HFC de controladas, líquidos dos impostos diferidos |
# | 4.02.06 | Mudança na participação relativa em controlada |
# | 4.02.06 | Realização de ganhos com ativos financeiros, líquida de tributos |
# | 4.02.06 | Ajustes acumulados de conversão |
# | 4.02.06 | IR / CSLL diferidos |
# | 4.02.06 | Perdas realizadas em operações de HFC originadas no exercício |
# | 4.02.06 | Equivalência patrimonial das perdas de HFC de controlada em conj., líquidas dos impostos diferido |
# | 4.02.06 | IR/CSLL diferidos |
# | 4.02.06 | Ajuste de hedge de fluxo de caixa |
# | 4.02.06 | Equivalência patrimonial - Perdas de HFC de controladas, líquidos dos impostos diferidos |
# | 4.02.06 | Equivalência patrimonial - Ganhos de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.06 | Ajuste de avaliação patrimonial |
# | 4.02.06 | Equivalência patrimonial - (Perdas) ganhos de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.06 | Equivalência patrimonial - (Perdas) ganhos de HFC controlada conj., líquidas dos impostos diferidos |
# | 4.02.06 | Mudança de participação em controlada |
# | 4.02.06 | Equivalência patrimonial - Ganhos (perdas) de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.06 | IR/ CSLL diferidos |
# | 4.02.06 | IR/ CSSL diferidos |
# | 4.02.07 | Ajuste de hedge de fluxo de caixa |
# | 4.02.07 | Equivalência patrimonial - Ganhos de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.07 | Equivalência patrimonial - (Perdas) ganhos de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.07 | Provisão de IR e CS não realizados |
# | 4.02.07 | Ajustes acumulados de conversão |
# | 4.02.07 | Mudança de participação em controlada em conjunto |
# | 4.02.07 | IR/CSLL diferidos |
# | 4.02.07 | Ganho/ (perdas) com derivativos, líquidos de impostos |
# | 4.02.07 | Ganho com derivativos |
# | 4.02.07 | Participação no resultado abrangente das subsidiárias, coligadas e sociedades de contr compartilhado |
# | 4.02.08 | IR/CSSL diferidos |
# | 4.02.08 | Participação no resultado abrangente das coligadas e controladas em conjunto |
# | 4.02.08 | Ajuste de hedge de fluxo de caixa |
# | 4.02.08 | Equivalência patrimonial - Ganhos (perdas) de HFC controlada conj., líquidos dos impostos diferidos |
# | 4.02.08 | IR/CSLL diferidos |
# | 4.02.08 | Valor justo de instrumentos financ disponíveis para venda |
# | 4.02.08 | Participação no resultado abrangente das controladas, coligadas e controladas em conjunto |
# | 4.02.08 | IR/ CSLL diferidos |
# | 4.02.08 | IR/ CSSL diferidos |
# | 4.02.09 | Valor justo de instrumentos financeiros disponíveis para venda |
# | 4.02.09 | Participação no resultado abrangente das controladas e coligadas |
# | 4.02.09 | Mudança de participação em controlada em conjunto |
# | 4.02.09 | IR/CSLL diferidos |
# | 4.02.09 | Variações de participação em controladas |
# | 4.02.09 | Ajuste de hedge de fluxo de caixa |
# | 4.02.10 | IR/CSSL diferidos |
# | 4.02.10 | IR/CSLL diferidos |
# | 4.02.10 | Participação no resultado abrangente das coligadas e entidades com controle compartilhado |
# | 4.02.10 | IR/ CSSL diferidos |
# | 4.02.10 | subsidiárias, coligadas e sociedades de controle compartilhado |
# | 4.02.11 | Participação no resultado abrangente das coligadas e entidades com controle compartilhado |
# | 4.02.11 | Participação no resultado abrangente das coligadas e enteidades com controle compartilhado |
# | 4.02.11 | Participação no resultado abrangente das subsidiárias, coligadas e sociedades de controle compartilh |
# | 4.02.11 | IR/CSLL diferidos |
# | 4.02.11 | Participação no result. abrangente das subsidiárias, coligadas e sociedades de controle compartilhad |
# | 4.02.11 | Participação no resultado abrangente das subsidiárias, coligadas e sociedades de controle compart. |
# | 4.02.11 | Instrumentos Financeiros ao Valor Justo por meio de ORA |
# | 4.02.12 | IR/CSSL diferidos |
# | 4.02.12 | IR/CSLL diferidos |
# | 4.02.12 | IR/ CSSL diferidos |
# | 4.02.13 | Participação no resultado abrangente das subsidiárias, coligadas e sociedades de controle compartilh |
# | 4.02.13 | Participação no result. abrangente das subsidiárias, coligadas e sociedades de controle compartilhad |
# | 4.02.14 | Variação de participação em controlada |
# | 4.02.14 | Variações de Participação em Controlada |
# | 4.03 | Resultado Abrangente Consolidado do Período |
# | 4.03.01 | Atribuído a Sócios da Empresa Controladora |
# | 4.03.02 | Atribuído a Sócios Não Controladores |
# | 5.01 | Capital Social Integralizado - Saldos Iniciais |
# | 5.01 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria -
01 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Reservas de Lucro - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Lucros ou Prejuízos Acumulados - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Outros Resultados Abrangentes - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Patrimônio Líquido - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Participação dos Não Controladores - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Patrimônio Líquido Consolidado - Ajustes de Adoção - CPC 48/IFRS 9 |
# | 5.02.01 | Capital Social Integralizado - Custo com captação |
# | 5.02.01 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria - Custo com captação |
# | 5.02.01 | Reservas de Lucro - Custo com captação |
# | 5.02.01 | Lucros ou Prejuízos Acumulados - Custo com captação |
# | 5.02.01 | Outros Resultados Abrangentes - Custo com captação |
# | 5.02.01 | Patrimônio Líquido - Custo com captação |
# | 5.02.01 | Participação dos Não Controladores - Custo com captação |
# | 5.02.01 | Patrimônio Líquido Consolidado - Custo com captação |
# | 5.02.01 | Capital Social Integralizado - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Reservas de Lucro - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Lucros ou Prejuízos Acumulados - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Outros Resultados Abrangentes - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Patrimônio Líquido - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Participação dos Não Controladores - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Patrimônio Líquido Consolidado - Ajuste de Adoção  - CPC 48/IFRS9 |
# | 5.02.01 | Capital Social Integralizado - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Reservas de Lucro - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Lucros ou Prejuízos Acumulados - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Outros Resultados Abrangentes - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Patrimônio Líquido - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Participação dos Não Controladores - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.01 | Patrimônio Líquido Consolidado - Aplicação inicial IFRS 9 (CPC 48), líquido de impostos |
# | 5.02.02 | Capital Social Integralizado - Transferência para a reserva de retenção de lucros |
# | 5.02.02 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria -

# | 5.04.08 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria - Incentivo fiscal SUDENE |
# | 5.04.08 | Reservas de Capital, Opções Outorgadas e Ações em Tesouraria - Custo de captação |
# | 5.04.08 | Reservas de Lucro - Incentivo fiscal SUDENE |
# | 5.04.08 | Reservas de Lucro - Custo de captação |
# | 5.04.08 | Lucros ou Prejuízos Acumulados - Incentivo fiscal SUDENE |
# | 5.04.08 | Lucros ou Prejuízos Acumulados - Custo de captação |
# | 5.04.08 | Outros Resultados Abrangentes - Incentivo fiscal SUDENE |
# | 5.04.08 | Outros Resultados Abrangentes - Custo de captação |
# | 5.04.08 | Patrimônio Líquido - Incentivo fiscal SUDENE |
# | 5.04.08 | Patrimônio Líquido - Custo de captação |
# ...
# | 6.03.06 | Outros |
# | 6.03.06 | Liquidação de Instrumentos financeiros |
# | 6.03.06 | Liquidações de instrumentos financeiros |
# | 6.03.06 | Depósitos vinculados |
# | 6.03.06 | Prêmio pago por outorga de opções de ações |
# | 6.03.06 | Pagamento de arrendamentos financeiros - principal |
# | 6.03.06 | Liquidação de instrumento financeiro |
# | 6.03.06 | Integralização de capital por acionista não controlador em controlada |
# | 6.03.06 | Pagamento de arrendamentos |
# | 6.03.06 | Pagamento de debêntures, líquidas de hedge |
# | 6.03.06 | Dividendos e Juros sobre Capital Proprios Pagos |
# | 6.03.06 | Caixa líquido proveniente das (usado nas) atividades operacionais das operações descontinuadas |
# | 6.03.06 | Partes relacionadas |
# | 6.03.06 | Pagamento de arrendamento |
# | 6.03.06 | Pagamento de parcelas de concessões a pagar |
# | 6.03.07 | Outros |
# | 6.03.07 | Pagamento de parcelamento de impostos |
# | 6.03.07 | Instrumentos derivativos recebidos, líquidos |
# | 6.03.07 | Transações com acionistas não controladores |
# | 6.03.07 | Recebimento de instrumentos financeiros derivativos |
# | 6.03.07 | Depósitos vinculados |
# | 6.03.07 | Empréstimos Tomados e Arrendamento Mercantil |
# | 6.03.07 | Pagamento de empréstimos, financiamentos e debêntures |
# | 6.03.07 | Pagamento de resgate de ações |
# | 6.03.07 | Amortizações de principal de passivo de arrendamentos |
# | 6.03.07 | Pagamento de arrendamentos - principal |
# | 6.03.07 | Instrumentos derivativos recebidos (pagos), líquidos |
# | 6.03.07 | Ingresso de dívidas |
# | 6.03.07 | Prêmio pago por outorga de opções de ações |
# | 6.03.07 | Recompra de ações |
# | 6.03.07 | Pagamento de dividendos e juros sobre o capital próprio |
# | 6.03.07 | Recurso Destinado para Aumento de Capital |
# | 6.03.07 | Caixa líquido (utilizado) gerado pelas atividades de financiamento de operações descontinuadas |
# | 6.03.07 | Pagamento de incorporação de redes |
# | 6.03.07 | Pagamento de dividendos |
# | 6.03.07 | Instrumentos derivativos pagos, líquidos |
# | 6.03.07 | Pagamento de arrendamentos |
# | 6.03.07 | Pagamentos Arrendamentos (Principal e Juros) |
# | 6.03.07 | Pagamentos Arrendamento |
# | 6.03.07 | Pagamento de Arrendamento Mercantil (principal e juros) |
# | 6.03.07 | Recebimento de instrumentos financeiro derivativos |
# | 6.03.07 | Aumento de capital |
# | 6.03.07 | Amortização do passivo de arrendamento |
# | 6.03.07 | Custos na Captação de Debêntures, Empréstimos e Financiamentos |
# | 6.03.09 | Remuneração paga aos acionistas não controladores |
# | 6.03.09 | Recompra de ações próprias |
# | 6.03.09 | Pagamentos de financiamentos e debêntures - juros |
# | 6.03.09 | Pagamento de principal de empréstimos e debêntures |
# | 6.03.09 | Incorporação ARN - Combinação de Negócios |
# | 6.03.09 | Integralização de capital por acionista não controlador |
# | 6.03.09 | Custos de transação no aumento de capital |
# | 6.03.09 | Outros |
# | 6.03.09 | Dividendos e JSCP pagos aos acionistas não controladoresRemuneração paga aos acionistas não controla |
# | 6.03.09 | Alienação de ações em tesouraria |
# | 6.03.09 | Depósitos vinculados ao serviço da dívida |
# | 6.03.09 | Pagamento de Eempréstimos, Financiamentos , Debêntures e Arrendamento Mercantil |
# | 6.03.09 | Mútuo com partes relacionadas - ingresso |
# | 6.03.09 | Caixa líquido utilizado pelas atividades de financiamento de operações descontinuadas |
# | 6.03.09 | Caixa líquido proveniente das (usado nas) atividades de financiamento das operações descontinuadas |
# | 6.03.09 | Parcelamento de encargos setoriais |
# | 6.03.09 | Dividendos e juros sobre capital próprio pagos aos acionistas não controladores |
# | 6.03.09 | Ações em tesouraria |
# | 6.03.09 | Aumento de capital |
# | 6.03.09 | Valores Recebidos de Debêntures, Empréstimos e Financiamentos |
# | 6.03.09 | Custos na captação de debêntures |
# | 6.03.09 | Pagamento aos acionistas dissidentes - incorporação de ações |
# | 6.03.09 | Caixa restrito |
# | 6.03.09 | Adiantamento para futuro aumento de capital |
# | 6.03.09 | Pagamentos de passivo de arrendamento - Outros |
# | 6.03.09 | Pagamento de Obrigações com CDE / Revitalização de bacias - principal |
# | 6.03.09 | Pagamento de arrendamentos |
# | 6.03.09 | Pagamento de Emprestimos,Financiamentos, Debentures eArrendamento Mercantil |
# | 6.03.09 | Pagamento de Emprestimos,Financiamentos, Debentures e Arrendamento Mercantil |
# | 6.03.10 | Pagamento de parcelamento de fornecedores |
# | 6.03.10 | Oferta pública de aquisição de ações da Neoenergia Pernambuco |
# | 6.03.10 | Aumento de capital |
# | 6.03.10 | Juros pagos debêntures - partes relacionadas |
# | 6.03.10 | Redução de Capital em Investimentos |
# | 6.03.10 | Mútuo com partes relacionadas - concedidos |
# | 6.03.10 | Recompra de ações próprias |
# | 6.03.10 | Caixa líquido proveniente das (usado nas) atividades de financiamento das operações descontinuadas |
# | 6.03.10 | Dividendos e juros sobre o capital próprio pagos |
# | 6.03.10 | Outros |
# | 6.03.10 | Parcelamento de encargos setoriais |
# | 6.03.10 | (Pagamento) recebimento por liquidação de instrumentos financeiros derivativos |
# | 6.03.10 | Recebimento por liquidação de instrumentos financeiros derivativos |
# | 6.03.10 | Depósitos vinculados ao serviço da dívida |
# | 6.03.10 | Recebimento de instrumentos financeiro derivativos |
# | 6.03.10 | Aumento de capital em investidas por minoritários |
# | 6.03.10 | Custos na captação de empréstimos e financiamentos |
# | 6.03.10 | Pagamento de Obrigações com CDE / Revitalização de bacias - principal |
# | 6.03.10 | Recebimento (Pagamento) por liquidação de instrumentos financeiros derivativos |
# | 6.03.10 | Recompra de ações em tesouraria |
# | 6.03.10 | Oferta pública de aquisição de ações da Neoenergia Cosern |
# | 6.03.10 | Pagamento de juros antecipação de recebíveis |
# | 6.03.10 | Custo com captação e aumento de capital social |
# | 6.03.10 | Liquidações de instrumentos financeiros |
# | 6.03.10 | Recompra de ações |
# | 6.03.10 | (Pagamento) por liquidação de instrumentos financeiros derivativos |
# | 6.03.10 | Aumento de capital social |
# | 6.03.10 | Liquidação de instrumentos financeiros derivativos |
# | 6.03.10 | Contratos de Mutuo |
# | 6.03.10 | Pagamento de arrendamento |
# | 6.03.11 | Custos relacionados a Ações em tesouraria adquiridas |
# | 6.03.11 | Amortização do passivo de arrendamento |
# | 6.03.11 | Recompra de ações próprias |
# | 6.03.11 | Pagamento de Arrendamento |
# | 6.03.11 | Mútuo com partes relacionadas |
# | 6.03.11 | Recompra de ações em tesouraria |
# | 6.03.11 | Dividendos e juros sobre o capital próprio pagos |
# | 6.03.11 | Caixa líquido (utilizado) gerado pelas atividades de financiamento de operações descontinuadas |
# | 6.03.11 | Custos relacionados ao aumento de capital |
# | 6.03.11 | Pagamento parcelamento de fornecedores |
# | 6.03.11 | Novos parcelamento de impostos |
# | 6.03.11 | Outros |
# | 6.03.11 | Ações em tesouraria |
# | 6.03.11 | Recompra de ações |
# | 6.03.11 | Alienação de participação societária em controladas |
# | 6.03.11 | Ganho na participação relativa das controladas |
# | 6.03.11 | Custos com captações de empréstimos, financiamentos e debentures |
# | 6.03.11 | Caixa líquido proveniente das (usado nas) atividades de financiamento das operações descontinuadas |
# | 6.03.11 | Custo de captações |
# | 6.03.11 | Aquisição de participação em controlada dos acionistas não controladores |
# | 6.03.11 | Captação em antecipação de recebíveis |
# | 6.03.11 | Caixa líquido gerado (utilizado) pelas atividades de financiamento de operações descontinuadas |
# | 6.03.11 | Antecipação de recebíveis futuros |
# | 6.03.12 | Aquisição de participação adicional de não controladores |
# | 6.03.12 | Adiantamento para futuro aumento de capital |
# | 6.03.12 | Aumento de capital |
# | 6.03.12 | Aumento de financiamento/ emprestimo - curto prazo |
# | 6.03.12 | Oferta pública de aquisição de ações da Neoenergia Cosern |
# | 6.03.12 | Caixa líquido gerado (utilizado) pelas atividades de financiamento de operações descontinuadas |
# | 6.03.12 | Parcelamento de impostos |
# | 6.03.12 | Aumento de capital com subscrição de ações |
# | 6.03.12 | Aumento de capital com subscrição de ação |
# | 6.03.12 | Recompra de ações em tesouraria |
# | 6.03.12 | Recompra de ações próprias |
# | 6.03.12 | Venda de ações em tesouraria |
# | 6.03.12 | Dividendos pagos para acionistas não controladores |
# | 6.03.12 | Pagamento de comissão antecipação de debentures e antecipação de recebiveis |
# | 6.03.12 | Alienação de ações em tesouraria |
# | 6.03.12 | Alienação de participação em controlada sem perda de controle |
# | 6.03.12 | Caixa líquido proveniente das (usado nas) atividades de financiamento das operações descontinuadas |
# | 6.03.12 | Aquisição de participação em controlada dos acionistas não controladores |
# | 6.03.12 | Outros |
# | 6.03.13 | Pagamento por arrendamento financeiro mercantil |
# | 7.01 | Receitas |
# | 7.01.01 | Vendas de Mercadorias, Produtos e Serviços |
# | 7.01.02 | Outras Receitas |
# | 7.01.03 | Receitas refs. à Construção de Ativos Próprios |
# | 7.01.04 | Provisão/Reversão de Créds. Liquidação Duvidosa |
# | 7.02 | Insumos Adquiridos de Terceiros |
# | 7.02.01 | Custos Prods., Mercs. e Servs. Vendidos |
# | 7.02.02 | Materiais, Energia, Servs. de Terceiros e Outros |
# | 7.02.03 | Perda/Recuperação de Valores Ativos |
# | 7.02.04 | Outros |
# | 7.03 | Valor Adicionado Bruto |
# | 7.04 | Retenções |
# | 7.04.01 | Depreciação, Amortização e Exaustão |
# | 7.04.02 | Outras |
# | 7.05 | Valor Adicionado Líquido Produzido |
# | 7.06 | Vlr Adicionado Recebido em Transferência |
# | 7.06.01 | Resultado de Equivalência Patrimonial |
# | 7.06.02 | Receitas Financeiras |
# | 7.06.03 | Outros |
# | 7.07 | Valor Adicionado Total a Distribuir |
# | 7.08 | Distribuição do Valor Adicionado |
# | 7.08.01 | Pessoal |
# | 7.08.02 | Impostos, Taxas e Contribuições |
# | 7.08.03 | Remuneração de Capitais de Terceiros |
# | 7.08.04 | Remuneração de Capitais Próprios |
# | 7.08.05 | Outros |

# %%
command = """SELECT ACCOUNT_NUMBER, ACCOUNT_NAME, ACCOUNT_VALUE, VERSION, EXERC_ORDER, ANALYSIS_START_PERIOD_DATE, ANALYSIS_END_PERIOD_DATE 
FROM DFP_ITR_CVM 
WHERE CNPJ = '08.364.948/0001-38' AND REPORT_DATE = '2020-03-31'
ORDER BY ACCOUNT_NUMBER"""

# Connect to a SQLite database (or create it if it doesn't exist)
connection = sqlite3.connect(DATABASE_PATH)

# Create a cursor object using the connection
cursor = connection.cursor()

# Query the database
cursor.execute(command)

# Fetch column names
columns = (
    [description[0] for description in cursor.description] if cursor.description else []
)

# Fetch results
rows = cursor.fetchall()

# Close the cursor and connection
cursor.close()
connection.close()

# Format results as markdown table
if not rows:
    output = "No data found with given query"
else:
    # Create markdown table
    output = "| " + " | ".join(columns) + " |\n"
    output += "| " + " | ".join(["---" for _ in columns]) + " |\n"
    for row in rows:
        output += (
            "| "
            + " | ".join([str(cell) if cell is not None else "" for cell in row])
            + " |\n"
        )

print(output)
# Out:
# | ACCOUNT_NUMBER | ACCOUNT_NAME | ACCOUNT_VALUE | VERSION | EXERC_ORDER | ANALYSIS_START_PERIOD_DATE | ANALYSIS_END_PERIOD_DATE |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1 | Ativo Total | 19369732000.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1 | Ativo Total | 19920480000.0 | 1 | ÚLTIMO | NULL | 2020-03-31 |
# | 1.01 | Ativo Circulante | 5441876000.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1.01 | Ativo Circulante | 4967965000.0 | 1 | ÚLTIMO | NULL | 2020-03-31 |
# | 1.01.01 | Caixa e Equivalentes de Caixa | 1025204000.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1.01.01 | Caixa e Equivalentes de Caixa | 628105000.0 | 1 | ÚLTIMO | NULL | 2020-03-31 |
# | 1.01.02 | Aplicações Financeiras | 2868818000.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1.01.02 | Aplicações Financeiras | 2793743000.0 | 1 | ÚLTIMO | NULL | 2020-03-31 |
# | 1.01.03 | Contas a Receber | 1298221000.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1.01.03 | Contas a Receber | 1308161000.0 | 1 | ÚLTIMO | NULL | 2020-03-31 |
# | 1.01.04 | Estoques | 10445000.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1.01.04 | Estoques | 9723000.0 | 1 | ÚLTIMO | NULL | 2020-03-31 |
# | 1.01.05 | Ativos Biológicos | 0.0 | 1 | PENÚLTIMO | NULL | 2019-12-31 |
# | 1